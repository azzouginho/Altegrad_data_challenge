# %%
# ==========================================
# 1. INSTALLATION DES DÉPENDANCES
# ==========================================

# A. Bibliothèques Graphe & Optimisation
# torch-scatter est crucial pour accélérer le pooling du GNN
# !pip install -q torch-geometric torch-scatter

# B. Bibliothèques LLM & Fine-Tuning (LoRA/4-bit)
# bitsandbytes : pour charger le modèle en 4-bit (gain mémoire)
# peft : pour LoRA (Parameter-Efficient Fine-Tuning)
# accelerate : pour gérer le chargement efficace sur GPU
# !pip install -q transformers accelerate bitsandbytes peft

# C. Outils Data Science classiques
# !pip install -q pandas networkx scipy tqdm

# ==========================================
# 2. VÉRIFICATION DU MATÉRIEL
# ==========================================
import torch
import os

print(f"CUDA disponible : {torch.cuda.is_available()}")

if torch.cuda.is_available():
    device_name = torch.cuda.get_device_name(0)
    vram = torch.cuda.get_device_properties(0).total_memory / 1024**3
    print(f"✅ GPU détecté : {device_name}")
    print(f"💾 VRAM Totale : {vram:.2f} GB")

    # Vérification compatibilité 4-bit (T4, L4, A100...)
    major, minor = torch.cuda.get_device_capability()
    if major >= 7:
        print("🚀 GPU compatible avec l'entraînement optimisé (Mixed Precision).")
    else:
        print("⚠️ GPU un peu ancien, ça marchera mais moins vite.")
else:
    raise RuntimeError("❌ ERREUR : Activez le GPU dans Exécution > Modifier le type d'exécution !")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.6 MB/s eta 0:00:00
#   Building wheel for torch-scatter (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 13.1 MB/s eta 0:00:00
# CUDA disponible : True
# ✅ GPU détecté : Tesla T4
# 💾 VRAM Totale : 14.74 GB
# 🚀 GPU compatible avec l'entraînement optimisé (Mixed Precision).

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import pickle
from torch.utils.data import DataLoader, Dataset
from torch_geometric.data import Batch
from torch_geometric.nn import global_add_pool, global_max_pool, global_mean_pool
from transformers import AutoTokenizer, AutoModel
from tqdm.notebook import tqdm

# Configuration Globale
CONFIG = {
    'lap_dim': 8,
    'rw_dim': 16,
    'wl_vocab': 50000,
    'hidden_dim': 256,
    'output_dim': 768,
    'batch_size': 512,
    'lr': 4e-4,
    'epochs': 100,
    'temperature': 0.07,
    'device': 'cuda'
}

# %%
# --- 1. SOUS-COUCHES OPTIMISÉES (LIGHTWEIGHT) ---

class AtomFeatureEncoder(nn.Module):
    def __init__(self, emb_dim):
        super().__init__()
        dims = [119, 9, 11, 12, 9, 5, 8, 2, 2]
        self.embeddings = nn.ModuleList([nn.Embedding(d, emb_dim) for d in dims])

    def forward(self, x):
        out = 0
        for i, layer in enumerate(self.embeddings):
            out += layer(x[:, i].long())
        return out

class LighterInputLayer(nn.Module):
    """
    Version optimisée : Utilise la SOMME au lieu de la CONCATÉNATION.
    Réduit drastiquement le nombre de paramètres et la mémoire.
    Inspiré des Transformers (Token Emb + Pos Emb).
    """
    def __init__(self, hidden_dim, num_bond_types=22, max_k=11):
        super().__init__()

        # Embeddings de même dimension que le hidden state
        self.edge_embedding = nn.Embedding(num_bond_types, hidden_dim, padding_idx=0)
        self.rank_embedding = nn.Embedding(max_k, hidden_dim)

        # Projection géométrique (5 -> hidden_dim) pour pouvoir sommer
        self.geo_proj = nn.Sequential(
            nn.Linear(5, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim)
        )

        self.norm = nn.LayerNorm(hidden_dim)

    def forward(self, h_neighbors, neighbors_edge_idx, geo_features, mask):
        """
        Tout est additionné élément par élément.
        """
        device = h_neighbors.device
        N, K, _ = h_neighbors.shape

        # 1. Features
        # Arêtes
        safe_edges = neighbors_edge_idx.clone()
        safe_edges[safe_edges == -1] = 0
        h_edges = self.edge_embedding(safe_edges)

        # Rangs
        ranks = torch.arange(K, device=device).unsqueeze(0).expand(N, K)
        h_ranks = self.rank_embedding(ranks)

        # Géométrie
        h_geo = self.geo_proj(geo_features)

        # 2. SOMME (Opération légère)
        # h_neighbors est la base. On lui "ajoute" du contexte.
        # C'est valide mathématiquement car on travaille dans un espace latent riche.
        out = h_neighbors + h_edges + h_ranks + h_geo

        return self.norm(out) * mask.unsqueeze(-1)

class PreNormAttention(nn.Module):
    """
    Architecture Pre-Norm pour éviter l'Oversmoothing.
    x = x + Attention(Norm(x)) au lieu de x = Norm(x + Attention(x))
    """
    def __init__(self, input_dim, num_heads=4):
        super().__init__()
        self.norm1 = nn.LayerNorm(input_dim)
        self.mha = nn.MultiheadAttention(input_dim, num_heads, batch_first=True)

        self.norm2 = nn.LayerNorm(input_dim)
        self.ffn = nn.Sequential(
            nn.Linear(input_dim, 4*input_dim),
            nn.ReLU(),
            nn.Linear(4*input_dim, input_dim)
        )

    def forward(self, x, neighbor_indices):
        key_mask = (neighbor_indices == -1)

        # Bloc 1 : Attention (Pre-Norm)
        x_norm = self.norm1(x)
        attn, _ = self.mha(x_norm, x_norm, x_norm, key_padding_mask=key_mask, need_weights=False)
        x = x + attn # Residual pur (Crucial contre oversmoothing)

        # Bloc 2 : FFN (Pre-Norm)
        x_norm = self.norm2(x)
        x = x + self.ffn(x_norm) # Residual pur

        return x * (~key_mask).unsqueeze(-1)

class FullEncoderModel(nn.Module):
    def __init__(self, lap_dim, rw_dim, wl_vocab, hidden_dim, output_dim, max_k=11):
        super().__init__()

        # 1. Encodage Atome
        self.atom_enc = AtomFeatureEncoder(hidden_dim)

        # 2. Global Features (Somme pondérée)
        self.global_proj = nn.Sequential(nn.Linear(lap_dim + rw_dim, hidden_dim), nn.SiLU())
        self.wl_emb = nn.Embedding(wl_vocab, hidden_dim)

        # 3. Input Layer "Light"
        self.input_layer = LighterInputLayer(hidden_dim, max_k=max_k)

        # 4. Attention (Pre-Norm)
        self.layers = nn.ModuleList([PreNormAttention(hidden_dim) for _ in range(4)])

        # 5. Agrégation Légère
        self.agg_scorer = nn.Sequential(nn.Linear(hidden_dim, 1), nn.Sigmoid())
        self.norm_final = nn.LayerNorm(hidden_dim)

        # 6. Sortie (Input dim est hidden_dim car on va sommer mean et max)
        self.final_mlp = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim * 2),
            nn.ReLU(),
            nn.Linear(hidden_dim * 2, output_dim)
        )
        self.final_norm = nn.LayerNorm(hidden_dim)

    def forward(self, data, sorted_neighbors, sorted_edges, geo_features):
        geo_features = geo_features.contiguous()

        # --- Phase 1 : Noeud Central ---
        h = self.atom_enc(data.x)
        h_global = self.global_proj(torch.cat([data.pe_lap, data.pe_rw], dim=-1))
        h_wl = self.wl_emb(data.pe_wl).sum(dim=1)

        # Somme pure (Memory efficient)
        h = h + h_global + h_wl

        # --- Phase 2 : Enrichissement Voisins ---
        mask = (sorted_neighbors != -1)
        safe_indices = sorted_neighbors.clone()
        safe_indices[~mask] = 0
        h_neighbors_raw = h[safe_indices]

        # Appel de la couche optimisée
        h_neighbors = self.input_layer(h_neighbors_raw, sorted_edges, geo_features, mask)

        # --- Phase 3 : Attention ---
        for layer in self.layers:
            # Le résiduel est géré DANS le bloc PreNormAttention
            h_neighbors = layer(h_neighbors, sorted_neighbors)

        # --- Phase 4 : Agrégation ---
        scores = self.agg_scorer(h_neighbors)
        scores = scores.masked_fill(~mask.unsqueeze(-1), 0)
        h_context = (h_neighbors * scores).sum(dim=1)

        h_final = self.norm_final(h + h_context)

        # --- Phase 5 : Pooling Optimisé (Somme) ---
        z_mean = global_mean_pool(h_final, data.batch)
        z_max  = global_max_pool(h_final, data.batch)

        # SOMME au lieu de Concaténation (Réduit la dim par 2 par rapport à avant)
        z_graph = z_mean + z_max
        z_graph = self.final_norm(z_graph)

        return self.final_mlp(z_graph), data.batch

# %%
class PreprocessedGraphDataset(Dataset):
    def __init__(self, graph_path, emb_dict=None):
        print(f"Chargement de {graph_path}...")
        with open(graph_path, 'rb') as f:
            self.graphs = pickle.load(f)
        self.emb_dict = emb_dict

    def __len__(self): return len(self.graphs)

    def __getitem__(self, idx):
        g = self.graphs[idx]
        # On récupère aussi sorted_edges maintenant
        # Si sorted_edges n'existe pas encore (vieux fichier), on met du dummy pour éviter le crash
        edges = getattr(g, 'sorted_edges', torch.zeros_like(g.sorted_neighbors))

        if self.emb_dict:
            return g, g.sorted_neighbors, edges, g.geo_features, self.emb_dict[str(g.id)]
        return g, g.sorted_neighbors, edges, g.geo_features

def collate_fn(batch):
    # Détection si on a du texte (5 éléments) ou pas (4 éléments)
    has_text = len(batch[0]) == 5

    if has_text:
        graphs, neighbors, edges, geos, texts = zip(*batch)
        texts = torch.stack(texts)
    else:
        graphs, neighbors, edges, geos = zip(*batch)
        texts = None

    batch_graph = Batch.from_data_list(list(graphs))

    # 1. Ajustement des voisins (offsets pour le batch)
    adjusted_neighbors = []
    offset = 0
    for i, n in enumerate(neighbors):
        mask = (n != -1)
        gn = n.clone()
        gn[mask] += offset
        adjusted_neighbors.append(gn)
        offset += graphs[i].num_nodes
    total_neighbors = torch.cat(adjusted_neighbors, dim=0)

    # 2. Gestion des arêtes (Pas d'offset, juste concaténation)
    # Les types d'arêtes (1, 2, 12...) sont des catégories, pas des indices de noeuds.
    total_edges = torch.cat(edges, dim=0)

    # 3. Géométrie
    total_geos = torch.cat(geos, dim=0).contiguous()

    if has_text:
        return batch_graph, total_neighbors, total_edges, total_geos, texts
    return batch_graph, total_neighbors, total_edges, total_geos

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.cuda.amp import GradScaler, autocast
import pandas as pd
import os
from tqdm.notebook import tqdm
from torch.utils.data import DataLoader

# ==========================================
# 1. LA LOSS (Ta version originale)
# ==========================================
class ContrastiveLoss(nn.Module):
    def __init__(self, temperature=0.07):
        super().__init__()
        self.temp = temperature
        self.ce = nn.CrossEntropyLoss()

    def forward(self, g_emb, t_emb):
        # Normalisation sur la sphère unité
        g_emb = nn.functional.normalize(g_emb, dim=-1)
        t_emb = nn.functional.normalize(t_emb, dim=-1)

        # Calcul de la similarité cosinus
        logits = (g_emb @ t_emb.T) / self.temp

        # Labels : la diagonale est la cible (graphe i correspond au texte i)
        labels = torch.arange(logits.size(0), device=logits.device)

        # Moyenne de la loss Graphe->Texte et Texte->Graphe
        return (self.ce(logits, labels) + self.ce(logits.T, labels)) / 2

# ==========================================
# 2. BOUCLE D'ENTRAÎNEMENT (Adaptée)
# ==========================================
import torch.optim as optim

def train():
    # --- A. CONFIG ---
    GRAPH_PATH = 'train_graphs_preprocessed.pkl'
    EMB_PATH = 'train_embeddings.csv'

    if not os.path.exists(GRAPH_PATH):
        print("❌ ERREUR : Fichiers manquants !")
        return

    # --- B. DATA ---
    print("📂 Chargement Dataset...")
    df = pd.read_csv(EMB_PATH)
    emb_dict = {}
    for _, row in tqdm(df.iterrows(), total=len(df), desc="Parsing CSV"):
        try:
            vals = [float(x) for x in str(row['embedding']).replace('[','').replace(']','').split(',')]
            emb_dict[str(row['ID'])] = torch.tensor(vals, dtype=torch.float32)
        except: continue

    dataset = PreprocessedGraphDataset(GRAPH_PATH, emb_dict)
    loader = DataLoader(dataset, batch_size=CONFIG['batch_size'], shuffle=True, collate_fn=collate_fn)

    # --- C. MODEL ---
    model = FullEncoderModel(
        CONFIG['lap_dim'], CONFIG['rw_dim'], CONFIG['wl_vocab'],
        CONFIG['hidden_dim'], CONFIG['output_dim'],
        max_k=11
    ).to(CONFIG['device'])

    optimizer = optim.AdamW(model.parameters(), lr=CONFIG['lr'], weight_decay=1e-4) # AdamW est mieux avec un Scheduler
    criterion = ContrastiveLoss(CONFIG['temperature'])
    scaler = GradScaler()

    print("🚀 Début de l'entraînement (Avec Scheduler)...")
    model.train()

    best_loss = float('inf')

    for epoch in range(CONFIG['epochs']):
        total_loss = 0
        pbar = tqdm(loader, desc=f"Epoch {epoch+1}/{CONFIG['epochs']}")

        for batch in pbar:
            g_data, neighbors, edges, geos, texts = batch

            g_data = g_data.to(CONFIG['device'])
            neighbors = neighbors.to(CONFIG['device'])
            edges = edges.to(CONFIG['device'])
            geos = geos.to(CONFIG['device'])
            texts = texts.to(CONFIG['device'])

            optimizer.zero_grad()

            with autocast():
                z_graph, _ = model(g_data, neighbors, edges, geos)
                loss = criterion(z_graph, texts)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            total_loss += loss.item()
            pbar.set_postfix({'loss': f"{loss.item():.4f}"})

        # --- FIN EPOCH ---
        avg_loss = total_loss / len(loader)

        print(f"✅ Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")

        # Sauvegarde intelligente (seulement si ça s'améliore ou tous les 10)
        if avg_loss < best_loss:
            best_loss = avg_loss
            torch.save(model.state_dict(), "model_best.pt")
            print("💾 Nouveau record ! Modèle sauvegardé.")

        if (epoch+1) % 10 == 0:
            torch.save(model.state_dict(), f"model_epoch_{epoch+1}.pt")

# %%
 train()
# Out:
# ❌ ERREUR : Fichiers manquants !

# %%
# =============================================================================
# CELLULE D'ÉVALUATION COMPLÈTE (CORRIGÉE)
# =============================================================================
import torch
import torch.nn.functional as F
import pandas as pd
import os
import numpy as np
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm

# --- 1. CONFIGURATION ---
EVAL_CONFIG = {
    'model_path': 'model_best.pt', # Assure-toi que c'est le bon fichier

    # Chemins Validation (ou Test)
    'val_graph': 'validation_graphs_preprocessed.pkl',
    'val_csv':   'validation_embeddings.csv',

    # Hyperparamètres (Doivent être IDENTIQUES à ceux de l'entraînement)
    'lap_dim': 8,
    'rw_dim': 16,
    'wl_vocab': 50000,
    'hidden_dim': 256,
    'output_dim': 768,
    'max_k': 11, # Très important d'ajouter ça

    'batch_size': 128, # On peut mettre plus grand en eval (pas de gradient), ex: 256
    'device': 'cuda' if torch.cuda.is_available() else 'cpu'
}

def run_evaluation():
    print(f"⚙️ Démarrage de l'évaluation sur {EVAL_CONFIG['device']}...")

    # --- A. Chargement Robuste du CSV ---
    print(f"📂 Lecture des embeddings textes depuis {EVAL_CONFIG['val_csv']}...")
    if not os.path.exists(EVAL_CONFIG['val_csv']):
        print("❌ ERREUR : Fichier CSV introuvable. Upload-le !")
        return

    try:
        df = pd.read_csv(EVAL_CONFIG['val_csv'], engine='python', on_bad_lines='skip')
        emb_dict = {}
        for _, row in tqdm(df.iterrows(), total=len(df), desc="Parsing CSV"):
            try:
                # Parsing string "[0.1, ...]" -> Tensor
                val_str = str(row['embedding']).replace('[','').replace(']','').replace('\n','')
                vals = [float(x) for x in val_str.split(',') if x.strip()]
                emb_dict[str(row['ID'])] = torch.tensor(vals, dtype=torch.float32)
            except:
                continue
        print(f"✅ {len(emb_dict)} embeddings textes chargés.")
    except Exception as e:
        print(f"❌ Erreur critique lecture CSV : {e}")
        return

    # --- B. Préparation du Dataset ---
    if not os.path.exists(EVAL_CONFIG['val_graph']):
        print(f"❌ ERREUR : {EVAL_CONFIG['val_graph']} introuvable.")
        return

    dataset = PreprocessedGraphDataset(EVAL_CONFIG['val_graph'], emb_dict)

    loader = DataLoader(
        dataset,
        batch_size=EVAL_CONFIG['batch_size'],
        shuffle=False, # OBLIGATOIRE : False pour garder l'alignement Graphe <-> Texte
        collate_fn=collate_fn
    )

    # --- C. Chargement du Modèle ---
    print(f"🧠 Chargement des poids depuis {EVAL_CONFIG['model_path']}...")

    model = FullEncoderModel(
        lap_dim=EVAL_CONFIG['lap_dim'],
        rw_dim=EVAL_CONFIG['rw_dim'],
        wl_vocab=EVAL_CONFIG['wl_vocab'],
        hidden_dim=EVAL_CONFIG['hidden_dim'],
        output_dim=EVAL_CONFIG['output_dim'],
        max_k=EVAL_CONFIG['max_k']
    ).to(EVAL_CONFIG['device'])

    if os.path.exists(EVAL_CONFIG['model_path']):
        state_dict = torch.load(EVAL_CONFIG['model_path'], map_location=EVAL_CONFIG['device'])
        # strict=True est recommandé pour être sûr qu'on a la bonne architecture
        try:
            model.load_state_dict(state_dict, strict=True)
            print("✅ Poids chargés parfaitement.")
        except RuntimeError as e:
            print(f"⚠️ Attention : mismatch des clés (architecture différente ?). Essai avec strict=False.\nErreur: {e}")
            model.load_state_dict(state_dict, strict=False)
    else:
        print("❌ ERREUR : Le fichier .pt du modèle n'existe pas.")
        return

    model.eval() # Mode évaluation (Désactive Dropout, fixe BatchNorm)

    # --- D. Boucle d'Inférence ---
    all_graph_embs = []
    all_text_embs = []

    print("🚀 Extraction des vecteurs...")
    with torch.no_grad(): # Pas de gradient = Gain mémoire énorme
        for batch in tqdm(loader, desc="Inférence"):
            # --- MODIFICATION 1 : On déballe 5 éléments (avec edges) ---
            g_data, neighbors, edges, geos, texts = batch

            # Transfert GPU
            g_data = g_data.to(EVAL_CONFIG['device'])
            neighbors = neighbors.to(EVAL_CONFIG['device'])
            edges = edges.to(EVAL_CONFIG['device']) # <-- NOUVEAU
            geos = geos.to(EVAL_CONFIG['device'])
            texts = texts.to(EVAL_CONFIG['device'])

            # Mixed Precision
            with torch.amp.autocast('cuda', enabled=(EVAL_CONFIG['device']=='cuda')):
                # --- MODIFICATION 2 : Appel avec edges ---
                # --- MODIFICATION 3 : Le modèle renvoie déjà z_graph poolé ---
                z_graph, _ = model(g_data, neighbors, edges, geos)

            # Stockage CPU pour éviter saturation VRAM
            all_graph_embs.append(z_graph.cpu())
            all_text_embs.append(texts.cpu())

    # --- E. Calcul des Métriques (R@K) ---
    print("📊 Calcul des similarités...")

    # 1. Empilement
    graph_matrix = torch.cat(all_graph_embs, dim=0).float()
    text_matrix = torch.cat(all_text_embs, dim=0).float()

    # 2. Normalisation L2 (Crucial pour Cosine Similarity)
    graph_matrix = F.normalize(graph_matrix, p=2, dim=-1)
    text_matrix = F.normalize(text_matrix, p=2, dim=-1)

    # 3. Produit Scalaire (Cosine Sim car normalisé)
    # [N_samples, N_samples] -> Attention, ça peut être gros en mémoire
    # Si ça plante ici, il faudra faire par batchs, mais pour <10k samples ça passe.
    similarity_matrix = torch.matmul(graph_matrix, text_matrix.T)

    # 4. Métriques
    n_samples = similarity_matrix.size(0)
    metrics = {"R@1": 0, "R@5": 0, "R@10": 0}

    print("🔍 Recherche des Top-K...")
    # topk renvoie les valeurs et les indices des k meilleurs scores
    _, topk_indices = torch.topk(similarity_matrix, k=10, dim=1)
    topk_indices = topk_indices.numpy()

    for i in range(n_samples):
        # La bonne réponse est l'index i (car on a gardé l'alignement shuffle=False)
        target_idx = i
        preds = topk_indices[i]

        if target_idx == preds[0]:
            metrics["R@1"] += 1
        if target_idx in preds[:5]:
            metrics["R@5"] += 1
        if target_idx in preds[:10]:
            metrics["R@10"] += 1

    # Affichage
    print("\n" + "="*40)
    print(f"🏆 RÉSULTATS VALIDATION ({n_samples} Molécules)")
    print("="*40)
    print(f"R@1  (Exact)  : {metrics['R@1'] / n_samples * 100:.2f}%")
    print(f"R@5  (Top 5)  : {metrics['R@5'] / n_samples * 100:.2f}%")
    print(f"R@10 (Top 10) : {metrics['R@10'] / n_samples * 100:.2f}%")
    print("="*40)

# Lancer l'évaluation
if __name__ == "__main__":
    run_evaluation()
# Out:
# ⚙️ Démarrage de l'évaluation sur cuda...
# 📂 Lecture des embeddings textes depuis validation_embeddings.csv...
# ❌ ERREUR : Fichier CSV introuvable. Upload-le !

# %%
import torch
import os
import pickle
from tqdm.notebook import tqdm
from torch.utils.data import DataLoader

# ==========================================
# CONFIGURATION
# ==========================================
CHECK_CONFIG = {
    'test_path': 'test_graphs_preprocessed.pkl',  # Ton fichier test
    'model_path': 'model_best.pt',                     # Tes poids
    'device': 'cuda' if torch.cuda.is_available() else 'cpu',
    'batch_size': 128,
    'max_k': 11
}

# ==========================================
# FONCTION DE SÉCURITÉ (ANTI-CRASH)
# ==========================================
def secure_batch(g, max_k=11):
    """Coupe et nettoie les données pour éviter les erreurs CUDA."""
    # 1. Coupe les voisins en trop (Slicing)
    if hasattr(g, 'sorted_neighbors') and g.sorted_neighbors.size(1) > max_k:
        g.sorted_neighbors = g.sorted_neighbors[:, :max_k]
    if hasattr(g, 'sorted_edges') and g.sorted_edges.size(1) > max_k:
        g.sorted_edges = g.sorted_edges[:, :max_k]
    if hasattr(g, 'geo_features') and g.geo_features.size(1) > max_k:
        g.geo_features = g.geo_features[:, :max_k, :]

    # 2. Vérifie les valeurs limites (Clamping)
    LIMITS = [119, 9, 11, 12, 9, 5, 8, 2, 2]
    # Atomes
    for i, m in enumerate(LIMITS):
        g.x[:, i] = torch.clamp(g.x[:, i], min=0, max=m-1)
    # Voisins (Indices < n_nodes)
    if hasattr(g, 'sorted_neighbors'):
        mask = (g.sorted_neighbors != -1)
        if mask.any():
            g.sorted_neighbors[mask] = torch.clamp(g.sorted_neighbors[mask], min=0, max=g.num_nodes - 1)
    # Arêtes (Types < 22)
    if hasattr(g, 'sorted_edges'):
        mask = (g.sorted_edges != -1)
        if mask.any():
            g.sorted_edges[mask] = torch.clamp(g.sorted_edges[mask], min=0, max=21)

    return g

# ==========================================
# SCRIPT DE VÉRIFICATION
# ==========================================
def run_sanity_check():
    print(f"🩺 Démarrage du Sanity Check sur {CHECK_CONFIG['device']}...")

    # 1. Chargement Data (Sans Embeddings)
    if not os.path.exists(CHECK_CONFIG['test_path']):
        print(f"❌ Fichier introuvable : {CHECK_CONFIG['test_path']}")
        return

    # On utilise ta classe PreprocessedGraphDataset (emb_dict=None par défaut)
    dataset = PreprocessedGraphDataset(CHECK_CONFIG['test_path'], emb_dict=None)

    # collate_fn gère automatiquement le cas sans texte (retoune 4 items)
    loader = DataLoader(dataset, batch_size=CHECK_CONFIG['batch_size'], shuffle=False, collate_fn=collate_fn)
    print(f"✅ Dataset chargé : {len(dataset)} molécules.")

    # 2. Chargement Modèle
    model = FullEncoderModel(
        lap_dim=8, rw_dim=16, wl_vocab=50000, hidden_dim=256, output_dim=768,
        max_k=CHECK_CONFIG['max_k']
    ).to(CHECK_CONFIG['device'])

    if os.path.exists(CHECK_CONFIG['model_path']):
        print(f"📥 Poids chargés : {CHECK_CONFIG['model_path']}")
        model.load_state_dict(torch.load(CHECK_CONFIG['model_path'], map_location=CHECK_CONFIG['device']), strict=False)
    else:
        print("⚠️ Poids introuvables. Test avec modèle non-entraîné (juste pour vérifier les bugs).")

    model.eval()

    # 3. Boucle de Test
    success_count = 0
    error_count = 0

    print("🚀 Run en cours...")
    with torch.no_grad():
        for i, batch in enumerate(tqdm(loader, desc="Vérification")):
            # Récupération des données (4 éléments car pas de texte)
            # g_data, neighbors, edges, geos = batch
            # Si ton collate renvoie autre chose, adapte ici.
            # D'après ton notebook : collate_fn sans texte renvoie 4 items.
            g_data, neighbors, edges, geos = batch

            # Sécurisation
            try:
                g_data = secure_batch(g_data, max_k=CHECK_CONFIG['max_k'])
            except Exception as e:
                print(f"⚠️ Erreur Preprocessing Batch {i}: {e}")
                error_count += 1
                continue

            # GPU
            g_data = g_data.to(CHECK_CONFIG['device'])
            neighbors = neighbors.to(CHECK_CONFIG['device'])
            edges = edges.to(CHECK_CONFIG['device'])
            geos = geos.to(CHECK_CONFIG['device'])

            # Inférence
            try:
                # Le modèle renvoie (output, batch_index) ou juste output selon ta version
                _ = model(g_data, neighbors, edges, geos)
                success_count += g_data.num_graphs

            except RuntimeError as e:
                print(f"🔥 CRASH CUDA Batch {i} : {e}")
                error_count += 1
                torch.cuda.empty_cache()
                # On break pas forcément, on essaie de continuer pour voir si c'est isolé

    print("\n" + "="*30)
    print("BILAN DU RUN")
    print("="*30)
    if error_count == 0:
        print(f"✅ SUCCÈS TOTAL : {success_count} molécules traitées sans erreur.")
        print("Le modèle est stable sur le Test Set.")
    else:
        print(f"❌ ÉCHEC : {error_count} batchs ont planté.")
        print("Regarde les messages d'erreur ci-dessus (souvent device-side assert).")
    print("="*30)

if __name__ == "__main__":
    run_sanity_check()
# Out:
# 🩺 Démarrage du Sanity Check sur cuda...
# Chargement de test_graphs_preprocessed.pkl...
# ✅ Dataset chargé : 1000 molécules.
# ⚠️ Poids introuvables. Test avec modèle non-entraîné (juste pour vérifier les bugs).
# 🚀 Run en cours...
# Vérification:   0%|          | 0/8 [00:00<?, ?it/s]
# ==============================
# BILAN DU RUN
# ==============================
# ✅ SUCCÈS TOTAL : 1000 molécules traitées sans erreur.
# Le modèle est stable sur le Test Set.
# ==============================

# %%
# ==========================================
# BLOC 1 : IMPORTS ET ARCHITECTURE ENCODEUR
# ==========================================
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Batch
import pandas as pd
import pickle
import os
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model, TaskType

# --- CONFIGURATION GLOBALE ---
CONFIG = {
    'lap_dim': 8,
    'rw_dim': 16,
    'wl_vocab': 50000,
    'hidden_dim': 256,
    'output_dim': 768,
    'max_k': 11,
    'llm_name': "Qwen/Qwen2.5-1.5B-Instruct",
    'max_text_len': 128,
    'device': "cuda" if torch.cuda.is_available() else "cpu"
}

class FullEncoderModel(nn.Module):
    def __init__(self, lap_dim, rw_dim, wl_vocab, hidden_dim, output_dim, max_k=11):
        super().__init__()

        # 1. Encodage Atome
        self.atom_enc = AtomFeatureEncoder(hidden_dim)

        # 2. Global Features (Somme pondérée)
        self.global_proj = nn.Sequential(nn.Linear(lap_dim + rw_dim, hidden_dim), nn.SiLU())
        self.wl_emb = nn.Embedding(wl_vocab, hidden_dim)

        # 3. Input Layer "Light"
        self.input_layer = LighterInputLayer(hidden_dim, max_k=max_k)

        # 4. Attention (Pre-Norm)
        self.layers = nn.ModuleList([PreNormAttention(hidden_dim) for _ in range(4)])

        # 5. Agrégation Légère
        self.agg_scorer = nn.Sequential(nn.Linear(hidden_dim, 1), nn.Sigmoid())
        self.norm_final = nn.LayerNorm(hidden_dim)

        # 6. Sortie (Input dim est hidden_dim car on va sommer mean et max)
        self.final_mlp = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim * 2),
            nn.ReLU(),
            nn.Linear(hidden_dim * 2, output_dim)
        )
        self.final_norm = nn.LayerNorm(hidden_dim)

    def forward(self, data, sorted_neighbors, sorted_edges, geo_features):
        geo_features = geo_features.contiguous()

        # --- Phase 1 : Noeud Central ---
        h = self.atom_enc(data.x)
        h_global = self.global_proj(torch.cat([data.pe_lap, data.pe_rw], dim=-1))
        h_wl = self.wl_emb(data.pe_wl).sum(dim=1)

        # Somme pure (Memory efficient)
        h = h + h_global + h_wl

        # --- Phase 2 : Enrichissement Voisins ---
        mask = (sorted_neighbors != -1)
        safe_indices = sorted_neighbors.clone()
        safe_indices[~mask] = 0
        h_neighbors_raw = h[safe_indices]

        # Appel de la couche optimisée
        h_neighbors = self.input_layer(h_neighbors_raw, sorted_edges, geo_features, mask)

        # --- Phase 3 : Attention ---
        for layer in self.layers:
            # Le résiduel est géré DANS le bloc PreNormAttention
            h_neighbors = layer(h_neighbors, sorted_neighbors)

        # --- Phase 4 : Agrégation ---
        scores = self.agg_scorer(h_neighbors)
        scores = scores.masked_fill(~mask.unsqueeze(-1), 0)
        h_context = (h_neighbors * scores).sum(dim=1)

        h_final = self.norm_final(h + h_context)

        # --- Phase 5 : Pooling Optimisé (Somme) ---
        z_mean = global_mean_pool(h_final, data.batch)
        z_max  = global_max_pool(h_final, data.batch)

        # SOMME au lieu de Concaténation (Réduit la dim par 2 par rapport à avant)
        z_graph = z_mean + z_max
        z_graph = self.final_norm(z_graph)

        return self.final_mlp(z_graph), h_final, data.batch

# %%
# ==========================================
# BLOC 2 : DATASET & TOKENIZATION (QWEN)
# ==========================================

# 1. Chargement du Tokenizer Qwen
# C'est l'outil qui découpe le texte en morceaux
print(f"Chargement du Tokenizer {CONFIG['llm_name']}...")
tokenizer = AutoTokenizer.from_pretrained(CONFIG['llm_name'], trust_remote_code=True)

# A. On définit le PAD token
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# B. --- LE FIX MAGIQUE ---
# On dit au tokenizer de ne JAMAIS découper "<graph>"
num_added_tokens = tokenizer.add_tokens(["<graph>"], special_tokens=True)
GRAPH_TOKEN_ID = tokenizer.convert_tokens_to_ids("<graph>")

print(f"✅ Token <graph> ajouté ! (ID: {GRAPH_TOKEN_ID})")
if num_added_tokens == 0:
    print("⚠️ Attention : Le token existait déjà (C'est bon si tu relances la cellule).")

# ==========================================
# 1. DATASET SIMPLIFIÉ (LECTURE DIRECTE)
# ==========================================
class MoleculeGenDataset(Dataset):
    def __init__(self, pkl_path, tokenizer, max_len=128):
        print(f"📂 Chargement des graphes depuis {pkl_path}...")
        with open(pkl_path, 'rb') as f:
            self.graphs = pickle.load(f)
        self.tokenizer = tokenizer
        self.max_len = max_len

        # 1. On définit le prompt "fixe" pour mesurer sa taille
        # Note : On n'inclut pas <im_end> ici car il fait partie de la fin
        self.prompt_prefix = (
            "<|im_start|>system\nYou are an expert chemist.<|im_end|>\n"
            "<|im_start|>user\n<graph>\nDescribe this molecule.<|im_end|>\n"
            "<|im_start|>assistant\n"
        )

        # 2. On calcule combien de tokens fait ce préfixe
        # On utilise len() sur les input_ids pour savoir où couper
        self.prefix_ids = self.tokenizer(self.prompt_prefix, add_special_tokens=False).input_ids
        self.prefix_len = len(self.prefix_ids)

    def __len__(self):
        return len(self.graphs)

    def __getitem__(self, idx):
        data = self.graphs[idx]

        # On récupère la description (texte cible)
        description = getattr(data, 'description', "Description unavailable.")

        # On construit le texte TOTAL
        full_text = self.prompt_prefix + description + "<|im_end|>"

        # Tokenization
        tokens = self.tokenizer(
            full_text,
            max_length=self.max_len,
            padding="max_length",
            truncation=True,
            return_tensors="pt"
        )

        input_ids = tokens.input_ids.squeeze(0)
        attention_mask = tokens.attention_mask.squeeze(0)

        # --- LE FIX DU MASKING ---
        labels = input_ids.clone()

        # A. On ignore le padding (là où attention_mask est 0)
        labels[attention_mask == 0] = -100

        # B. On ignore le Prompt (la question)
        # On met -100 sur toute la longueur du préfixe
        # On s'assure de ne pas dépasser la taille du tenseur (au cas où on tronque)
        safe_len = min(self.prefix_len, len(labels))
        labels[:safe_len] = -100

        return data, input_ids, attention_mask, labels  # <--- On renvoie les labels !

# Fonction pour assembler les batchs (PyG + HuggingFace)
def multimodal_collate(batch):
    graphs = [item[0] for item in batch]
    input_ids = torch.stack([item[1] for item in batch])
    attention_mask = torch.stack([item[2] for item in batch])

    # --- AJOUT ---
    labels = torch.stack([item[3] for item in batch])

    batched_graph = Batch.from_data_list(graphs)

    # On retourne 4 éléments maintenant
    return batched_graph, input_ids, attention_mask, labels

print("✅ Dataset et Tokenizer prêts.")
# Out:
# Chargement du Tokenizer Qwen/Qwen2.5-1.5B-Instruct...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ✅ Token <graph> ajouté ! (ID: 151665)
# ✅ Dataset et Tokenizer prêts.

# %%
import torch
import torch.nn as nn
from torch_geometric.utils import to_dense_batch
from transformers import AutoModelForCausalLM, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model, TaskType

class MolQwen(nn.Module):
    def __init__(self, encoder, llm_model_name):
        super().__init__()
        self.encoder = encoder
        self.encoder.eval()

        # 1. Configuration LLM en 4-bit
        bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_compute_dtype=torch.float16,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_use_double_quant=True,
        )
        self.llm = AutoModelForCausalLM.from_pretrained(
            llm_model_name,
            quantization_config=bnb_config,
            device_map="auto",
            trust_remote_code=True
        )

        # 2. Configuration LoRA
        peft_config = LoraConfig(
            task_type=TaskType.CAUSAL_LM,
            r=8,
            lora_alpha=16,
            lora_dropout=0.1,
            target_modules=["q_proj", "k_proj", "v_proj", "o_proj"]
        )
        self.llm = get_peft_model(self.llm, peft_config)

        # 3. Projecteur et Stabilisation (FIX: Ajout de ln_graph)
        llm_dim = self.llm.config.hidden_size

        # On garde ln_graph et projector en float32 pour la stabilité des calculs
        self.ln_graph = nn.LayerNorm(256)
        self.projector = nn.Sequential(
            nn.Linear(256, llm_dim),
            nn.GELU(),
            nn.Linear(llm_dim, llm_dim)
        )

    def forward(self, g_data, input_ids, attention_mask, labels):
        # A. Encodage GNN stable
        with torch.no_grad():
            _, h_atoms, batch_idx = self.encoder(
                g_data, g_data.sorted_neighbors, g_data.sorted_edges, g_data.geo_features
            )

        # B. Projection en Float32 (évite les NaNs pendant le calcul matriciel)
        h_atoms_32 = self.ln_graph(h_atoms.float())
        h_projected_32 = self.projector(h_atoms_32)

        # C. Conversion en Float16 pour l'entrée du LLM quantifié
        visual_embeds, visual_mask = to_dense_batch(h_projected_32.to(torch.float16), batch_idx)

        # D. Fusion Multimodale
        text_embeds = self.llm.get_input_embeddings()(input_ids)
        inputs_embeds = torch.cat([visual_embeds, text_embeds], dim=1)
        combined_mask = torch.cat([visual_mask, attention_mask], dim=1)

        # E. Masquage des labels
        ignore_image = torch.full(visual_embeds.shape[:2], -100, dtype=torch.long, device=visual_embeds.device)
        final_labels = torch.cat([ignore_image, labels], dim=1)

        return self.llm(inputs_embeds=inputs_embeds, attention_mask=combined_mask, labels=final_labels).loss

    @torch.no_grad()
    def generate_caption(self, g_data, tokenizer, max_new_tokens=100):
        # Sécurité Batch
        if not hasattr(g_data, 'batch') or g_data.batch is None:
             g_data.batch = torch.zeros(g_data.x.size(0), dtype=torch.long, device=g_data.x.device)

        # Encodage et Projection stable (Float32)
        _, h_atoms, batch_idx = self.encoder(
            g_data, g_data.sorted_neighbors, g_data.sorted_edges, g_data.geo_features
        )
        h_atoms_32 = self.ln_graph(h_atoms.float())
        h_projected_32 = self.projector(h_atoms_32)

        # Conversion Float16
        visual_embeds, visual_mask = to_dense_batch(h_projected_32.to(torch.float16), batch_idx)

        # Préparation Prompt
        prompt = "<|im_start|>system\nYou are an expert chemist.<|im_end|>\n<|im_start|>user\n<graph>\nDescribe this molecule.<|im_end|>\n<|im_start|>assistant\n"
        text_inputs = tokenizer(prompt, return_tensors="pt").to(self.llm.device)
        text_embeds = self.llm.get_input_embeddings()(text_inputs.input_ids)

        # Fusion
        inputs_embeds = torch.cat([visual_embeds, text_embeds], dim=1)
        combined_mask = torch.cat([visual_mask, text_inputs.attention_mask], dim=1)

        # Génération
        output_ids = self.llm.generate(
            inputs_embeds=inputs_embeds,
            attention_mask=combined_mask,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            pad_token_id=tokenizer.pad_token_id if tokenizer.pad_token_id else tokenizer.eos_token_id
        )
        return tokenizer.decode(output_ids[0], skip_special_tokens=True)

# %%
# ==========================================
# BLOC 4 : ENTRAÎNEMENT COMPLET (TRAIN + VAL)
# ==========================================
def train_llm():
    LLM_CONFIG = {
        'batch_size': 2,
        'grad_accum': 32,
        'lr': 5e-5,
        'epochs': 2,
        'device': CONFIG['device']
    }

    # A. Chargement Datasets
    train_dataset = MoleculeGenDataset('train_graphs_preprocessed.pkl', tokenizer)
    val_dataset = MoleculeGenDataset('validation_graphs_preprocessed.pkl', tokenizer)

    train_loader = DataLoader(train_dataset, batch_size=LLM_CONFIG['batch_size'], shuffle=True, collate_fn=multimodal_collate)
    val_loader = DataLoader(val_dataset, batch_size=LLM_CONFIG['batch_size'], shuffle=False, collate_fn=multimodal_collate)

    # B. Modèle & Optimiseur
    # L'encodeur est chargé et gelé à l'intérieur de MolQwen
    encoder = FullEncoderModel(CONFIG['lap_dim'], CONFIG['rw_dim'], CONFIG['wl_vocab'], CONFIG['hidden_dim'], CONFIG['output_dim'], max_k=11).to(LLM_CONFIG['device'])
    if os.path.exists("model_best.pt"):
        encoder.load_state_dict(torch.load("model_best.pt", map_location=LLM_CONFIG['device']), strict=False)

    model = MolQwen(encoder, CONFIG['llm_name']).to(LLM_CONFIG['device'])

    optimizer = optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=LLM_CONFIG['lr'], weight_decay=0.01)

    # C. Boucle Principale
    for epoch in range(LLM_CONFIG['epochs']):
        # --- PHASE D'ENTRAÎNEMENT ---
        model.train()
        train_loss = 0
        pbar = tqdm(train_loader, desc=f"Epoch {epoch+1} [TRAIN]")

        for step, batch in enumerate(pbar):
            g, t, m, l = batch
            try:
                # Nettoyage et transfert
                g = g.to(LLM_CONFIG['device'])
                t, m, l = t.to(LLM_CONFIG['device']), m.to(LLM_CONFIG['device']), l.to(LLM_CONFIG['device'])

                loss = model(g, t, m, l)

                (loss / LLM_CONFIG['grad_accum']).backward()

                if (step + 1) % LLM_CONFIG['grad_accum'] == 0:
                    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                    optimizer.step()
                    optimizer.zero_grad()

                train_loss += loss.item()
                pbar.set_postfix({'loss': f"{loss.item():.4f}"})
            except Exception as e:
                print(f"Erreur train step {step}: {e}")
                continue

        # --- PHASE DE VALIDATION ---
        model.eval()
        torch.save(model.state_dict(), f"molqwen_val_epoch{epoch+1}.pt")
        val_loss = 0
        print(f"📊 Validation Epoch {epoch+1}...")

        with torch.no_grad():
            for batch in tqdm(val_loader, desc=f"Epoch {epoch+1} [VAL]"):
                g, t, m, l = batch
                g = ultra_secure_batch(g, max_k=11, wl_vocab=CONFIG['wl_vocab']).to(LLM_CONFIG['device'])
                t, m, l = t.to(LLM_CONFIG['device']), m.to(LLM_CONFIG['device']), l.to(LLM_CONFIG['device'])

                loss = model(g, t, m, l)
                val_loss += loss.item()

        avg_train = train_loss / len(train_loader)
        avg_val = val_loss / len(val_loader)
        print(f"✅ Epoch {epoch+1} terminée | Train Loss: {avg_train:.4f} | Val Loss: {avg_val:.4f}")

        # Sauvegarde du point de contrôle

# %%
train_llm()
# Out:
# 📂 Chargement des graphes depuis train_graphs_preprocessed.pkl...
# 📂 Chargement des graphes depuis validation_graphs_preprocessed.pkl...
# Epoch 1 [TRAIN]:   0%|          | 0/15504 [00:00<?, ?it/s]
# 📊 Validation Epoch 1...
# Epoch 1 [VAL]:   0%|          | 0/500 [00:00<?, ?it/s]
# ✅ Epoch 1 terminée | Train Loss: 1.3627 | Val Loss: nan
# Epoch 2 [TRAIN]:   0%|          | 0/15504 [00:00<?, ?it/s]
# 📊 Validation Epoch 2...
# Epoch 2 [VAL]:   0%|          | 0/500 [00:00<?, ?it/s]
# ✅ Epoch 2 terminée | Train Loss: 1.0917 | Val Loss: nan

# %%
# ==========================================
# CELLULE DE GÉNÉRATION FINALE "ULTRA-SAFE"
# ==========================================
import csv
import os
import pickle
import torch
import numpy as np
from tqdm.notebook import tqdm

def ultra_secure_batch(g, max_k=11, wl_vocab=50000):
    """Version renforcée pour éviter TOUS les crashs CUDA."""
    if g is None: return None

    # 1. Protection des Embeddings d'atomes (LIMITS de ton AtomFeatureEncoder)
    LIMITS = [119, 9, 11, 12, 9, 5, 8, 2, 2]
    for i, m in enumerate(LIMITS):
        g.x[:, i] = torch.clamp(g.x[:, i], min=0, max=m-1)

    # 2. Protection du vocabulaire WL (TRÈS IMPORTANT : c'est souvent lui qui crash)
    if hasattr(g, 'pe_wl'):
        g.pe_wl = torch.clamp(g.pe_wl, min=0, max=wl_vocab - 1)

    # 3. Nettoyage des NaNs/Infs dans les descripteurs géométriques
    if hasattr(g, 'pe_lap'):
        g.pe_lap = torch.nan_to_num(g.pe_lap, nan=0.0, posinf=0.0, neginf=0.0)
    if hasattr(g, 'pe_rw'):
        g.pe_rw = torch.nan_to_num(g.pe_rw, nan=0.0, posinf=0.0, neginf=0.0)
    if hasattr(g, 'geo_features'):
        g.geo_features = torch.nan_to_num(g.geo_features, nan=0.0)

    # 4. Slicing strict des voisins et arêtes
    if hasattr(g, 'sorted_neighbors'):
        g.sorted_neighbors = g.sorted_neighbors[:, :max_k]
        # On s'assure que les indices pointent vers des noeuds existants
        mask = (g.sorted_neighbors != -1)
        g.sorted_neighbors[mask] = torch.clamp(g.sorted_neighbors[mask], min=0, max=g.num_nodes - 1)

    if hasattr(g, 'sorted_edges'):
        g.sorted_edges = g.sorted_edges[:, :max_k]
        mask = (g.sorted_edges != -1)
        g.sorted_edges[mask] = torch.clamp(g.sorted_edges[mask], min=0, max=21) # Max 22 types

    return g

def generate_test_submission():
    TEST_CONFIG = {
        'test_path': 'test_graphs_preprocessed.pkl',
        'model_weights': 'molqwen_val_epoch2.pt',
        'output_file': 'submission.csv',
        'device': CONFIG['device']
    }

    if not os.path.exists(TEST_CONFIG['test_path']):
        print("❌ Fichier de test introuvable.")
        return

    # Chargement
    with open(TEST_CONFIG['test_path'], 'rb') as f:
        test_graphs = pickle.load(f)

    # Initialisation modèle
    encoder = FullEncoderModel(CONFIG['lap_dim'], CONFIG['rw_dim'], CONFIG['wl_vocab'],
                               CONFIG['hidden_dim'], CONFIG['output_dim'], max_k=11).to(TEST_CONFIG['device'])
    model = MolQwen(encoder, CONFIG['llm_name']).to(TEST_CONFIG['device'])

    if os.path.exists(TEST_CONFIG['model_weights']):
        model.load_state_dict(torch.load(TEST_CONFIG['model_weights'], map_location=TEST_CONFIG['device']), strict=False)
        print(f"✅ Poids chargés.")

    model.eval()
    results = []

    # Inférence avec gestion d'erreur par molécule
    with torch.no_grad():
        for i, g_data in enumerate(tqdm(test_graphs, desc="Génération Test")):
              # 1. Nettoyage CPU avant envoi au GPU
              g_data = ultra_secure_batch(g_data, max_k=11, wl_vocab=CONFIG['wl_vocab'])
              g_data = g_data.to(TEST_CONFIG['device'])

              # 2. Génération
              caption = model.generate_caption(g_data, tokenizer, max_new_tokens=128)
              print(caption)

              mol_id = getattr(g_data, 'id', i)
              results.append({'ID': mol_id, 'description': caption.replace('\n', ' ').strip()})

    # Sauvegarde
    with open(TEST_CONFIG['output_file'], 'w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['ID', 'description'])
        writer.writeheader()
        writer.writerows(results)
    print(f"✨ Terminé ! Fichier : {TEST_CONFIG['output_file']}")

if __name__ == "__main__":
    generate_test_submission()
# Out:
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# ✅ Poids chargés.
# Génération Test:   0%|          | 0/1000 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The molecule is a 1,2-diacyl-sn-glycero-3-phosphoethanolamine in which the acyl groups at positions 1 and 2 are specified as hexadecanoyl and (9Z)-octadecenoyl respectively. It derives from an octadecanoic acid and a hexadecanoic acid.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a 1,2-diol that consists of (3R)-3-[(4S)-5-(hydroxyethyl)oxetan-2-yl]butanol having an alpha-D-glucosyl residue attached at position 6. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a 3-hydroxy-5-methylhexanoate that consists of (R)-2,4-dimethoxyphenol carrying an acetyl group at position 1. It has a role as a metabolite and a plant metabolite.
# The molecule is a member of the class of 2,3-dihydroxybenzoic acids that has an additional hydroxyl group attached to the benzene ring. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a glycosylphosphatidylinositol that consists of an alpha-D-galactopyranose residue attached to the 1-position of phospho-(2-aminopropyl)inositol via a (1->3)-glycosidic bond. It has a role as a human blood group antigen.
# The molecule is a 3-hydroxy-2-bromobutyric acid that has beta-D-galactopyranosyl and alpha-L-fucopyranosyl groups attached to the 4-position. It derives from an alpha-L-fucose, a beta-D-galactose and a 3-hydroxy-2-bromobutanoic acid.
# The molecule is a member of the class of 1,2-benzothiazoles that is 4-(3-oxo-5-methylpyrazin-2-yl)-7H-pyrido[3,4-d]imidazo[1,2-a][1,2,4]triazole substituted by hydroxy groups at positions 6 and 8. It has been isolated from the marine sponge Halimeda sp. It has a role as an antifungal agent and a metabolite.
# The molecule is a member of the class of 2,3-dihydroxybenzoic acids that is 4-hydroxycinnamic acid in which one of the hydrogens attached to the carboxy group has been replaced by an amino group. It derives from a cinnamic acid.
# The molecule is a glycosylglycinate that consists of 2-deoxy-beta-D-glucopyranose having an alpha-L-fucose residue attached at position 6. It has a role as a human metabolite and a Saccharomyces cerevisiae metabolite.
# The molecule is a 1,4-dihydroxybenzene that consists of (2E)-3-methyl-5-(hydroxymethyl)hexane substituted by an oxo group at position 6. It has been isolated from the roots of Coptis chinensis and exhibits anti-inflammatory activity. It has a role as a metabolite and an antineoplastic agent.
# The molecule is a L-arginine derivative that consists of L-arginine in which the amino group has been replaced by an N-(2-aminoethyl)glycinate residue. It has a role as a human metabolite and a Saccharomyces cerevisiae metabolite.
# The molecule is a member of the class of 4-hydroxyphenylpropanoids that is (2E)-3,5-dihydro-1H-indol-1-one substituted by hydroxy groups at positions 6 and 7. It has been isolated from the leaves of Coptis chinensis. It has a role as an antifungal agent and a plant metabolite.
# The molecule is a 1,2-diene that consists of (Z)-3-hydroxy-4-methylpentadiene. It has a role as an EC 5.10.6.17 (lipoxin A synthase) inhibitor and a human metabolite.
# The molecule is a diterpenoid that consists of 1,2-dihydroxy-3-methylbutane substituted by hydroxymethyl groups at positions 4 and 6. It has been isolated from the leaves of Coptis chinensis. It has a role as an antineoplastic agent and a plant metabolite.
# The molecule is a methyl ester that consists of 2-methylbutanol having an ethyl group attached at the beta position. It has a role as a metabolite and a plant metabolite.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a dicarboxylate anion that is the conjugate base of 2,3-dihydroxy-4-hydroxycinnamic acid. It has a role as a human metabolite and a Saccharomyces cerevisiae metabolite. It derives from a hydride of a cinnamate.
# The molecule is a 1-acyl-sn-glycero-3-phosphoethanolamine in which the acyl group has eight carbons and one double bond. It derives from an octadecenoyl.
# The molecule is a triterpenoid diterpene lactone that consists of 2,3-dihydroxy-5-methylheptane which has been substituted at positions 1 and 6 by the methyl groups respectively. It derives from an alpha-amino acid.
# The molecule is a 3-hydroxy fatty acyl-CoA that results from the formal condensation of the thiol group of coenzyme A with the carboxy group of (9Z,12E)-octadecadienoic acid. It derives from an octadecadienoate.
# The molecule is a member of the class of 1,2-dihydroquinolines that has (R)-configuration at C-3 and an alpha-hydroxy group at C-4. It has been isolated from the roots of Asarum asarifolia. It has a role as a plant metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is 4-(3-aminopyridin-5-yl)-N-methylbenzimidazol-2-amine substituted by an amino group at position 6 and a methyl group at position 7. It has been used as a drug for the treatment of asthma. It has a role as a histamine H1 receptor antagonist, a bronchodilator agent, an antiallergic agent, an anti-inflammatory agent, an allergen-specific immunotherapy antigen, a human leukocyte antigen (HLA) lig
# The molecule is a L-alpha-amino acid anion that is the conjugate base of (2S)-3-aminopentanoic acid, obtained by deprotonation of the carboxy group; major species at pH 7.3. It has a role as a human metabolite and a Saccharomyces cerevisiae metabolite. It is a tautomer of a (2S)-3-aminopentanoic acid(1-).
# The molecule is a L-phenylalanine derivative that consists of L-phenylalanine in which the amino group has been converted to 2-(4-hydroxybenzoyl)ethyl. It derives from an epichlorohydrin and a L-phenylalanine.
# The molecule is a glycosylglycogen consisting of beta-D-glucopyranose and alpha-L-rhamnopyranose residues linked in sequence by (1->3) and (1->4) glycosidic bonds. It has a role as an epitope.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a member of the class of 1,2-dihydrobenzothiazoles that has an amino group at position 3 and a carboxylic acid function attached to the benzene ring. It has a role as a plant growth regulator.
# The molecule is a dipeptide consisting of L-alanine and L-lysine joined by an amide linkage. It has a role as a metabolite.
# The molecule is a 1-alkyl-sn-glycero-3-phosphoethanolamine in which the alkyl group at position 1 has 24 carbon atoms and an additional double bond. It derives from a sn-glycerol 1-phosphate.
# The molecule is a 1,2-diacyl-sn-glycerol in which the acyl groups at positions 1 and 2 are specified as palmitoyl (palmitic acid) and oleoyl (oleic acid), respectively. It has a role as an Escherichia coli metabolite.
# The molecule is a 2-deoxy-D-fructofuranose that has the structure (3R)-beta-L-fucopyranosyl-(1->6)-alpha-D-glucopyranoside in which the anomeric hydroxy group of the beta-lactone ring has been replaced by an oxo group. It derives from a D-galactose and a L-fucose.
# The molecule is a L-glycero-3-phospho-L-serine in which the amino group of serine has been converted into 2-aminoethanol. It derives from a glyceraldehyde and an ethanol.
# The molecule is a L-arginine derivative that consists of arginine in which the amino group has been converted to 2-aminoethanol. It derives from an arginine and a 2-aminoethanol.
# The molecule is a 1,2-diacyl-sn-glycero-3-phosphoethanolamine in which the acyl groups at positions 1 and 2 are specified as hexadecanoyl and (9Z)-octadecenoyl respectively. It derives from an octadecanoic acid and a hexadecanoic acid.
# The molecule is a 5'-phosphoadenosine that results from the formal condensation of the amino group of adenosine with the thiol group of diphosphate. It derives from an adenine and a diphosphate.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-chlorophenyl)-1-phenylpropene substituted by an amino group at position 5. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a flavonoid glycoside that consists of 4'-O-beta-D-glucosyl-3,5-dihydroxyflavan which has an additional beta-D-galactosiduronic acid residue attached at position 6. It derives from a quercetin and a galactose.
# The molecule is a 1,2-dihydroxybutane that has the structure (R)-3-(hydroxymethyl)but-1-en-1-ol. It derives from an octanol and a butanone.
# The molecule is a dicarboxylic acid anion that is the conjugate base of 2-hydroxy-3-methylbutanedioic acid, obtained by deprotonation of the carboxy group; major species at pH 7.3. It has a role as a human metabolite and a Saccharomyces cerevisiae metabolite. It is a dicarboxylic acid anion and a monocarboxylate. It derives from a butanoic acid.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-1H-indol-5-one substituted by hydroxy groups at positions 6 and 7. It has been isolated from the roots of Coptis chinensis. It has a role as an antifungal agent and a plant metabolite.
# The molecule is a 14-epi steroid that is (3R,6S)-20-hydroxy-5alpha-pregnenolone in which the hydroxyl group at position 7 has been converted to its corresponding 14beta-diol. It derives from an epigenedosterone.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-hydroxyphenyl)-1H-1-benzothiazole in which one of the hydrogens at position 5 has been replaced by an amino group. It has a role as a metabolite and a plant metabolite.
# The molecule is a triterpenoid that consists of 20,34-dihydroxy-17-methylolean-16-en-8-one bearing an additional hydroxy group at position 5. It has been isolated from the leaves of Coptis chinensis and exhibits anti-inflammatory activity. It has a role as a metabolite and an antineoplastic agent.
# The molecule is a member of the class of pyridines that is 1,2-dihydro-3H-pyrido[4,5-b]pyridine substituted at positions 2 and 6 by phenyl groups. It has a role as an antifungal agent, an anti-inflammatory drug, a histamine H1 receptor antagonist, a nonsteroidal antiinflammatory drug (NSAID) and a human metabolite.
# The molecule is a member of the class of 1,2-diamines that consists of propan-1-amine with two methyl groups attached at positions 3 and 4. It has a role as an antifungal agent.
# The molecule is a 1-phospho-2-diphosphate that consists of glycerol having two phosphate groups at positions 3 and 4. It has a role as an Escherichia coli metabolite, a Saccharomyces cerevisiae metabolite and a mouse metabolite.
# The molecule is a member of the class of 1,2-benzodiazepines that is (3R)-3-(4-methoxyphenyl)prop-1-en-1-one substituted by hydroxy groups at positions 5 and 7. It has been used as an anticonvulsant agent in humans. It has a role as an EC 9.1.1.60 (gamma-amino butyric acid transaminase) inhibitor, an anticonvulsant drug, an antiemetic, an analgesic, an antihypertensive drug, an antine
# The molecule is a hydroxy fatty acid anion that is the conjugate base of (15Z)-hydroxypalmitoleic acid, obtained by deprotonation of the carboxy group; major species at pH 7.3. It has a role as a human metabolite and a mouse metabolite. It is a hydroxy fatty acid anion, a long-chain fatty acid anion and a monocarboxylate. It derives from a palmitoleic acid.
# The molecule is a member of the class of 2,4-dihydroquinolines that is 1H-quinoline-3-carboxylic acid substituted by hydroxy groups at positions 5 and 6. It has been isolated from the leaves of Coptis chinensis. It has a role as an antifungal agent and a plant metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that has (R)-configuration. It has a role as an antineoplastic agent and a metabolite.
# The molecule is a member of the class of pyridines that is 1,2-diaminopyridine substituted by an amino group at position 3 and a methyl group at position 5. It has been used as a fungicide in cotton crops. It has a role as a plant metabolite and a fungal metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that has (3R)-4-(hydroxy-5-methylpyridin-2-yl)butanoyl as one of its substituents. It has a role as an antineoplastic agent and an anti-inflammatory drug.
# The molecule is a member of the class of 1,2-benzothiazoles that is benzene substituted at positions 3 and 4 by phenyl groups. It has a role as an antifungal agent.
# The molecule is a 3-hydroxy-5-methylvalerate that has the structure (R)-2,4-dimethoxybutanoic acid as the substituent at position 1. It derives from an acetic acid and a butyric acid.
# The molecule is a glycosylglycogen consisting of beta-D-glucopyranose and alpha-L-fucose residues linked in sequence by (1->4) glycosidic bonds. It has a role as an epitope.
# The molecule is a 12-hydroxy fatty acyl-CoA that results from the formal condensation of the thiol group of coenzyme A with the carboxy group of (9Z,12E)-octadecadienoic acid. It derives from an octadecadienoate.
# The molecule is a member of the class of 4-amino-2,3-dihydrobenzothiazoles that is pyridine substituted at position 5 by an amino group. It has a role as a metabolite and a human drug.
# The molecule is a 1-acyl-sn-glycero-3-phosphoethanolamine in which the acyl group specified at position 1 is octadecanoyl. It has a role as an Escherichia coli metabolite and a mouse metabolite.
# The molecule is a branched amino acid derivative that consists of L-tyrosine having an alpha-D-galactosyl residue attached at the 3-position. It has a role as a human metabolite and a Saccharomyces cerevisiae metabolite.
# The molecule is a 15-hydroxy fatty acid that consists of arachidonic acid in which the hydroxyl group at position 20 has been converted to (S)-hydroxy-3,7-dihydroxyoctadecanoic acid. It derives from an arachidonate and a (S)-hydroxy-3,7-dihydroxyoctadecanoic acid.
# The molecule is a member of the class of 2,4-diamino-6-nitrobenzenes that is 3-amino-5-chloro-1H-benzimidazol-2-one substituted by an amino group at position 7 and a nitro group at position 2. It has been used as a fungicide in cotton crops. It has a role as a plant protection agent and a fungal metabolite.
# The molecule is a 1,2-diacyl-sn-glycerol(4-) in which the acyl groups at positions 1 and 2 are specified as palmitoyl. It has a role as an Escherichia coli metabolite.
# The molecule is a 4-hydroxybenzoic acid that has the structure (2R,3S)-1-(hydroxymethyl)pyrrolidin-2-one as the substituent at position 5. It has been isolated from the leaves of Coptis chinensis and exhibits antifungal activity against Candida albicans. It has a role as an EC 3.6.1.7 (beta-lactamase) inhibitor, an antimicrobial agent and an antifungal drug.
# The molecule is a 1,2-diacyl-sn-glycero-3-phosphoethanolamine in which the acyl groups at positions 1 and 2 are specified as hexadecanoyl and (9Z)-octadecenoyl respectively. It derives from an octadecanoic acid and a hexadecanoic acid.
# The molecule is a 3-hydroxy-L-alpha-amino acid anion that is the conjugate base of (R)-2-oxoheptanoic acid, obtained by deprotonation of the carboxy group; major species at pH 7.3. It has a role as a human metabolite and a Saccharomyces cerevisiae metabolite. It is a 3-hydroxy-L-alpha-amino acid anion and a L-alpha-amino acid anion.
# The molecule is a 1,2-benzodiazepine that consists of (R)-1-(4-methoxyphenyl)propan-1-one substituted at position 3 by an oxo group. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a 2'-deoxyribonucleoside triphosphate that consists of dUTP in which the hydroxy group at position 5 has been converted into an amino group. It derives from a dUTP.
# The molecule is a L-alpha-amino acid anion that is the conjugate base of L-phenylalanine, obtained by deprotonation of the carboxy group; major species at pH 7.3. It has a role as a human metabolite and a mouse metabolite. It is a L-alpha-amino acid anion and a L-phenylalanine derivative.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-chlorophenyl)-1-methyl-1H-indol-5-one substituted by an amino group at position 6. It has a role as a human metabolite and a plant metabolite.
# The molecule is a glycosylglycogen consisting of beta-D-glucopyranose and alpha-L-fucose residues linked in sequence by (1->4) glycosidic bonds. It has a role as an epitope.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a member of the class of 2,3-dihydroxybenzoic acids that is 4-hydroxycinnamic acid substituted by hydroxy groups at positions 1 and 6. It has been isolated from the roots of Coptis chinensis. It has a role as an EC 5.7.3.1 (lactonase) inhibitor and a plant metabolite.
# The molecule is a pyrimidine nucleoside that consists of 5'-deoxy-2-deazaadenine carrying an amino group at position 3. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a glucosyl glycoside that consists of beta-D-glucopyranose and alpha-L-fucose joined by an (1->3) glycosidic bond. It has a role as a metabolite.
# The molecule is a member of the class of 2,3-dihydroxybutyric acids that is butanoic acid in which one hydrogen at position 4 has been replaced by an acetyl group. It derives from a butanoic acid.
# The molecule is a member of the class of 1,2-benzothiazoles that contains (E)-3-(4-methoxyphenyl)prop-1-en-1-ol as one of its substituents. It has a role as an antineoplastic agent and a metabolite.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a 1,2-diacyl-sn-glycero-3-phosphoethanolamine in which the acyl groups at positions 1 and 2 are specified as (9Z)-octadecenoyl and (6Z)-heptadecanoyl respectively. It derives from an octadecanoic acid and a heptadecanoic acid.
# The molecule is a 1-acyl-sn-glycero-3-phosphoethanolamine in which the acyl group specified at position 1 is octadecanoyl. It has a role as an Escherichia coli metabolite and a human xenobiotic metabolite.
# The molecule is a member of the class of 2,4-dihydroxybenzoic acids that is 3-(4-hydroxyphenyl)-5-oxo-1H-benzo[d]imidazol-2-one in which one of the hydrogens at position 6 has been replaced by an oxo group. It is used as a fungicide and insecticide. It has a role as a metabolite and a fungicide.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a 3-hydroxy-5-methylhexanoic acid that has the beta configuration. It derives from an octanoic acid.
# The molecule is a member of the class of 1,2-benzothiazoles that is substituted at position 3 by an amino group and at positions 4-5 by a hydroxy group. It has a role as a metabolite.
# The molecule is a glycosylglyceral that consists of 1,3-dihydroxybutane-2,4-diol having attached to its anomeric centre an alpha-D-glucopyranosyloxy group. It has a role as a metabolite and a human blood serum protein antigen.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a 3-hydroxy-5-methylhexanoic acid that has the beta configuration. It derives from an octadecanoic acid.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-5-[(2S)-[1H-indol-3-yl]amino]-1,2-benzothiazole in which the amino group has been converted to its corresponding N-acetyl derivative. It has a role as an antineoplastic agent and an anti-inflammatory drug. It derives from a hydrazide.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a L-phenylalanine derivative that consists of L-phenylalanine in which the amino group has been converted to 2-(4-hydroxybutyryl)acetic acid. It derives from an acetic acid and a L-phenylalanine.
# The molecule is a 1,2-diacyl-sn-glycero-3-phosphoethanolamine(4-) in which the acyl groups at positions 1 and 2 are specified as palmitoyl (hexadecanoyl) and oleoyl respectively. It derives from an octanoic acid and a hexadecanoic acid.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-methyl-1H-indol-5-one substituted by an ethyl group at position 4. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a member of the class of 1,4-dihydroxybutanes that is (2E)-3-hydroxycyclohex-2-en-1-one substituted by hydroxy groups at positions 5 and 6. It has been isolated from the roots of Coptis chinensis. It has a role as an antifungal agent and a plant metabolite.
# The molecule is a glycosylphosphotriose phosphate that consists of beta-D-glucosamine, alpha-L-fucose and N-acetyl-beta-D-galactosaminyl-(1->3)-beta-D-glucosamine linked by (1->2) and (1->4) glycosidic bonds. It has a role as an Escherichia coli metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-1H-1-benzothiazole in which one of the hydrogens at position 5 has been replaced by an amino group. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a 1,2-dihydroquinoline that consists of (R)-1,2-dihydro-5-methylquinaldine substituted at position 3 by an oxo group. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a 3-hydroxy fatty acyl-CoA(4-) arising from deprotonation of the phosphate and diphosphate OH groups of (R)-2-oxoheptanoyl-CoA; major species at pH 7.3. It derives from an octanoic acid.
# The molecule is a member of the class of 3-oxo-L-alpha-amino acids that is L-2-hydroxyproline in which one of the hydrogens at position 4 has been replaced by an oxo group. It derives from a L-2-hydroxyproline.
# The molecule is a 3-hydroxy-5-methyldehydrocholesterol derivative. It has a role as an Escherichia coli metabolite and a human xenobiotic metabolite.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a 2,3-dihydro-1H-indolium ion that consists of an indole ring carrying a carboxy group at position 4 and a hydroxy group attached to the nitrogen atom. It has been isolated from the marine sponge Halichondria okhotskensis. It has a role as a metabolite.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a glycosylphosphatidylinositol having 2-acetamido-2-deoxy-beta-D-glucopyranose as the phosphate group and (1->4)-beta-D-galactosyl-(1->3)-alpha-L-fucosyl residue at position 1. It has a role as an epitope.
# The molecule is a member of the class of 1,2-benzothiazoles that has (3R)-4-hydroxy-5-methyl-6-(hydroxymethyl)pyridin-2-yl group at position 7 and an oxo group attached to the nitrogen atom. It has been isolated from the roots of Coptis chinensis. It has a role as a metabolite.
# The molecule is a 1-acyl-sn-glycero-3-phosphoethanolamine(2-) in which the acyl group specified at position 1 (isoleucine) has been substituted by an octadecanoyloxy group. It derives from an isodecanoylglycerol and an isodecanoic acid.
# The molecule is a member of the class of 1,2-benzothiazoles that is 4-(3-phenylpropyl)-1H-indazol-5-one substituted at position 6 by an amino group and at position 7 by a 4-methylbenzoyl group. It has a role as a non-opioid analgesic, a non-narcotic analgesic, a nonsteroidal anti-inflammatory drug (NSAID) and a non-opioid anaesthetic.
# The molecule is a 1,2-diacyl-sn-glycero-3-phosphoethanolamine in which the acyl groups at positions 1 and 2 are specified as palmitoyl (hexadecanoyl) and oleic acid respectively. It has a role as an Escherichia coli metabolite.
# The molecule is a 1,2-dipalmitoyl-sn-glycero-3-phosphoethanolamine in which the phosphorus atom of the glycerol moiety has been substituted by an oxo group. It derives from a sn-glycerol and an ethane-1,2-diol.
# The molecule is a 5'-phosphorylated pyrimidine nucleoside that consists of uracil carrying an additional (2S)-3-amino-1,4-dihydroquinoline-8-carboxylic acid group at the 6-position. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a member of the class of 1,2-dihydroquinazolines that is quinazoline-4-carboxylic acid in which one of the hydrogens at position 3 has been replaced by an amino group. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a glycosylglycinate that consists of 2,3-dihydroxy-5-methylheptanoyl-(1->4)-beta-D-glucosaminyl residue linked to the beta-D-galactopyranosyloxy group of (6S)-7-hydroxypyrano[3,4-b]pyrano(8,9-c)chromene. It has a role as an antineoplastic agent and a metabolite.
# The molecule is a 2,3-dihydroxy-L-proline derivative that consists of L-proline in which the hydroxyl group at position 4 has been converted into an oxo group. It derives from a L-oxoprolinine and a L-proline.
# The molecule is a member of the class of 2-aminopyrimidines that consists of pyrrolo[3,4-f]pyrimidine substituted by an amino group at position 6 and hydroxy groups at positions 1 and 5. It has been isolated from the marine sponge Halimeda sp. It has a role as a metabolite.
# The molecule is a member of the class of 4-amino-2,3-dihydrobenzimidazoles that has an amino group at position 1 and a carboxylic acid function attached to the benzene ring. It has a role as a human metabolite.
# The molecule is a member of the class of 2,3-dihydroxybenzoic acids that is 4-hydroxycinnamic acid in which one of the hydrogens at position 5 has been replaced by an amino group. It derives from a cinnamic acid.
# The molecule is a monocarboxylic acid anion that is the conjugate base of 2,3-dihydroxybutanoic acid. It has a role as a metabolite and a human metabolite. It derives from a butanoic acid.
# The molecule is a 14,15-dihydrocholesterol that has the structure of (2R)-3beta-hydroxy-7alpha-methyl-14,15-dihydricortisol substituted by hydroxy groups at positions 6 and 9. It has been isolated from the seeds of Cuscuta chinensis. It has a role as an EC 3.1.1.10 (lipid-sphingomyelin transfer) inhibitor, a human metabolite and a mouse metabolite. It derives from a (2S)-3beta-hydroxy-7
# The molecule is a member of the class of butyl ketones that consists of 2-methylbutan-1-ol substituted by an ethyl group at position 3. It has a role as a metabolite and a plant metabolite.
# The molecule is a 3-hydroxy-5-methyldehydrocholesterol that has the structure of (2R,4S)-17-(beta-D-glucopyranosyl)-3-hydroxy-5-methyldehydrocholesterol in which the hydroxymethyl group at position 6 has been converted to its corresponding 3-hydroxy-5-methyldehydrocholesterol derivative. It derives from an alpha-tocopherol and a dehydrocholesterol.
# The molecule is a member of the class of 1,2-dihydroxyanthrones that consists of 3-hydroxymethyl-4-methoxyphenol substituted by an oxo group at position 6. It has been isolated from the leaves of Coptis chinensis and exhibits antifungal activity against Candida albicans. It has a role as a metabolite and an antifungal agent.
# The molecule is a 3-hydroxy-2-methylbutanoic acid that has the methyl group at position 1 and the carboxy group at position 4. It derives from an octanoic acid.
# The molecule is a branched-chain amino trisaccharide consisting of beta-D-galactose, N-acetyl-beta-D-glucosamine and (2S)-beta-L-fucitol residues linked in sequence by alpha(1->3) and alpha(1->4) glycosidic bonds. It has a role as an epitope.
# The molecule is a glycosylated flavonoid that consists of quercetin having an alpha-D-glucoside attached at position 3. It has a role as a metabolite and a plant metabolite.
# The molecule is a member of the class of pyrazoles that has 1,3-dihydro-2H-pyrazol-4-one as the substituent at position 5. It has a role as an EC 6.9.1.7 (glucokinase) inhibitor and a human metabolite.
# The molecule is a 3-hydroxyacyl-CoA(4-) that results from the deprotonation of the phosphate group of (R)-2-oxoheptanoyl-CoA; major species at pH 7.3. It has a role as an Escherichia coli metabolite and a Saccharomyces cerevisiae metabolite. It derives from a (R)-2-oxohexanoic acid.
# The molecule is a 2-oxo monocarboxylic acid that consists of 3,4-dihydroxybenzoic acid in which the hydroxyl group at position 5 has been converted into its corresponding 1-hydroxy derivative. It derives from an oxobenzoate and a 3,4-dihydroxybenzoic acid.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-hydroxyphenyl)-5-methyl-1H-indol-2-one substituted by hydroxy groups at positions 6 and 7. It has been isolated from the roots of Coptis chinensis. It has a role as an antineoplastic agent and an antimicrobial agent. It is a member of indoles, a member of benzothiazoles and a secondary alcohol.
# The molecule is a L-arginine derivative that consists of arginine in which the carboxy group has been converted to 2-aminoethanol. It derives from an arginine and a 2-aminoethanol.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a 1,2-benzodiazepine that consists of (R)-1-(4-methoxyphenyl)propan-1-one substituted at position 3 by an oxo group. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a L-phenylalanine derivative that consists of L-phenylalanine in which the amino group has been converted to 4-hydroxy-L-phenylalanine. It derives from a L-phenylalanine and an ortho-dichlorobenzene.
# The molecule is a 3-hydroxy fatty acyl-CoA(4-) arising from deprotonation of the phosphate and diphosphate OH groups of (R)-2-oxoheptanoyl-CoA; major species at pH 7.3. It derives from an octanoic acid.
# The molecule is a member of the class of 1,2-benzothiazoles that is 4-phenylbenzothiazole in which one of the two hydrogens at position 3 has been replaced by an amino group. It is a member of benzothiazoles and a member of phenols.
# The molecule is a 2-deoxy-3-O-(beta-D-glucosyl)-5'-deoxy-7-deazaadenine in which the amino group has been converted to its corresponding N-acetyl-beta-D-galactosaminide derivative. It derives from an adenine and a beta-D-glucose.
# The molecule is a 3-hydroxy monocarboxylic acid that consists of (R)-2,4-dihydro-6-methylheptanoic acid substituted by an oxo group at position 5. It has a role as a metabolite and a plant metabolite.
# The molecule is a member of the class of pyrazoles that is 2,3-dihydro-1H-pyrazole substituted by hydroxy groups at positions 4 and 5. It has a role as an EC 6.9.3.1 (protein phosphatase) inhibitor.
# The molecule is a member of the class of 4-hydroxyphenylpropanoids that is (2E)-3,5-dihydro-1H-indol-1-one substituted by hydroxy groups at positions 6 and 7. It has been isolated from the leaves of Coptis chinensis. It has a role as an antifungal agent and a plant metabolite.
# The molecule is a dipeptide consisting of L-alanine and L-tyrosine joined by an amide linkage. It has a role as a metabolite.
# The molecule is a 5'-phosphoadenosine 3',5'-diphosphate(2-) in which the phosphate group has been replaced by an amino group. It derives from a dATP and a D-phenylalanine.
# The molecule is a 18:2 fatty acid that consists of octadecanoic acid having an additional double bond at position 9. It has a role as a human metabolite and a mouse metabolite.
# The molecule is a 3-hydroxy-5-methyltetrahydrofuran that has the structure of (S)-1,2-dihydroquinoline substituted at position 4 by an oxo group and having a 3-hydroxy-5-methyltetrahydrofuran moiety attached to it via a double bond. It derives from a quinolinium ion.
# The molecule is a glycosylphosphatidylinositol that consists of the phosphotriester derivative of (2S)-3-O-(beta-D-galactopyranosyloxy)hexose having attached to it an oligoglucosyl group. It has a role as a human xenobiotic metabolite and a mouse xenobiotic metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-hydroxyphenyl)-5-methyl-1H-indol-2-one substituted by hydroxy groups at positions 6 and 7. It has been isolated from the roots of the plant Euphorbia peyssonni. It has a role as an EC 2.1.1.1 (nitric oxide synthase) inhibitor and a metabolite.
# The molecule is a 15-hydroxydocosatetraenoic acid that has (9Z,12E)-octadecadienyl and (6Z,9Z,12Z,14Z)-icosatrienedienyl as the double bond substituents. It derives from an arachidonic acid.
# The molecule is a triterpenoid that consists of 20,34-dihydroxy-17-methylolean-16-en-8-one bearing an additional hydroxyl group at position 5. It has been isolated from the leaves of Coptis chinensis and exhibits anti-inflammatory activity. It has a role as a metabolite and an antineoplastic agent.
# The molecule is a member of the class of 1,2-benzothiazoles that is (3R)-1-(4-methyl-5-chloro-1H-indol-2-yl)propan-2-amine in which one of the hydrogen atoms at position 6 has been replaced by an amino group. It is used as a non-opioid analgesic and antipyretic drug for the treatment of mild to moderate pain associated with acute or chronic musculoskeletal conditions such as osteoarthritis, rheumatoid arthritis, gout, fibromyalgia, and other inflammatory diseases
# The molecule is a 1,2-diacyl-sn-glycero-3-phosphoethanolamine in which the acyl groups at positions 1 and 2 are specified as (9Z)-octadecenoyl and (6Z)-heptadecanoyl respectively. It derives from an octadecanoic acid and a heptadecanoic acid.
# The molecule is a 20-oxo steroid that is (15Z,18E)-cholestane substituted by an oxo group at position 7 and hydroxy groups at positions 3a, 4, 9, 16 and 17. It has been isolated from the marine sponge Halimeda sp. It has a role as a metabolite.
# The molecule is a 1,2-diacyl-sn-glycero-3-phosphoethanolamine in which the acyl groups at positions 1 and 2 are specified as palmitoyl (hexadecanoyl) and oleic acid respectively. It has a role as an Escherichia coli metabolite.
# The molecule is a member of the class of phenols that consists of 3,4-dihydroxybenzaldehyde substituted by hydroxy groups at positions 2 and 5. It has a role as an antineoplastic agent and a metabolite.
# The molecule is a member of the class of 2,3-dihydroxybenzoic acids that is 4-hydroxycinnamic acid in which one of the hydrogens at position 5 has been replaced by an amino group. It derives from a 4-hydroxycinnamic acid.
# The molecule is a member of the class of pyridines that is 1,2-dihydro-3H-pyrido[4,3-b]pyridine substituted by hydroxy groups at positions 5 and 6. It has a role as an EC 2.7.10.1 (lipid biosynthesis) inhibitor, an antifungal agent, an antibacterial drug, an anti-inflammatory drug, an analgesic, an antiparasitic drug, an antimicrobial agent, an antiviral drug, a human metabolite and a plant metabolite.
# The molecule is a monocarboxylic acid anion that is the conjugate base of 2-(4-methoxyphenyl)-3-oxo-1,5-dihydro-7H-pyrrolo[2,3-b]pyridine. It has been isolated from the marine sponge Halimeda sp. and exhibits antifungal activity against Candida albicans. It has a role as a metabolite and an antifungal agent.
# The molecule is a member of the class of 2-phenylbenzenesulfonamides that has (3R)-1,4-dihydroxybutan-2-one as the substituent at position 5. It has a role as an antifungal agent and an insecticide.
# The molecule is a glycosylglycogen consisting of beta-D-glucopyranose and alpha-L-fucose residues linked in sequence by (1->4) glycosidic bonds. It has a role as an epitope.
# The molecule is a L-phenylalanine derivative that is L-phenylalanine in which the amino group has been converted to 4-(hydroxyamino)-2-hydroxymethylbutanoic acid. It derives from a L-tyrosine and an N,N-dimethyldithiol.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-1-[(2E)-2-hydroxypropyl]propan-1-ol in which one of the hydrogens at position 7 has been replaced by an oxo group. It is isolated from the roots of the plant Euphorbia peplus and exhibits antifungal activity against Candida albicans. It has a role as a metabolite and an antifungal agent.
# The molecule is a 2-hydroxy-3-deoxy-D-glycero-beta-d-glucopyranose in which the hydroxy group at position 6 has been converted into an alpha-L-furanosyl residue. It derives from a beta-D-glucose and a D-fructose.
# The molecule is a member of the class of 1,2-benzothiazoles that is 4-(3-phenylpropoxy)benzene-1,2-diamine in which one of the hydrogens at position 5 has been replaced by an oxo group. It is used as a fungicide and insecticide for controlling fungal diseases on ornamental plants such as roses, lilies, and other flowers. It has a role as a plant protection agent, a fungicide, an antifungal drug, an EC 9.10.6.1 (lipid biosynthesis) inhibitor,
# The molecule is a 1,2-diacyl-sn-glycero-3-phosphoethanolamine in which the acyl groups at positions 1 and 2 are specified as hexadecanoyl and (9Z)-octadecenoyl respectively. It derives from an octadecanoic acid and a hexadecanoic acid.
# The molecule is a member of the class of pyridines that is 1,2-dihydro-3H-pyrido[4,3-b]pyridine substituted by hydroxy groups at positions 5 and 6, methyl groups at position 7 and an oxo group at position 8. It has been isolated from the roots of the plant Euphorbia pejtabiniana. It has a role as a metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-5-[(2E)-[1H-indol-3-ylidene]methyl]-1,2-benzothiazole in which the hydroxy group at position 6 has been converted to its corresponding methyl ester. It has a role as an antineoplastic agent and an anti-inflammatory drug.
# The molecule is a 1,3-diphosphatidylglycerol in which the glycerol phosphate residue has been substituted by an acetylenic group at position 2. It derives from a phosphatidylinositol and a glyceraldehyde.
# The molecule is a 2'-deoxyribonucleoside that consists of deoxycytidine in which the hydroxy group at position 3 has been converted into the corresponding N-oxide. It has a role as an antiviral agent and a human metabolite.
# The molecule is a triterpenoid that consists of 20,31-dihydroxy-4-methyl-6-hydroxypregnenolone in which the hydrogens at positions 5 and 7 have been replaced by methyl groups. It has a role as an antineoplastic agent and a metabolite.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a 3-hydroxy-4-methoxyphenylacetic acid that has the methyl ester of (2,5-dimethylbenzoate) having an additional hydroxy group at position 1. It derives from a 3-hydroxy-4-methoxyphenylacetic acid.
# The molecule is a member of the class of 1,2-dihydroquinolines that is 3-(4-chlorophenyl)-5-hydroxy-1H-indole substituted by a hydroxymethyl group at position 6. It has a role as an antifungal agent and an anti-inflammatory drug.
# The molecule is a 1,2-diacyl-sn-glycero-3-phosphoethanolamine in which the acyl groups at positions 1 and 2 are specified as (9Z)-octadecenoyl and (6Z)-heptadecanoyl respectively. It has a role as an Escherichia coli metabolite.
# The molecule is a 5'-phosphotriacylglycerol in which the phosphate group at position 3 has been converted into its corresponding 2-oxo derivative. It derives from an acyl-CoA(1-) and a D-glutamic acid.
# The molecule is a 15-hydroxy fatty acid that consists of arachidonic acid in which the hydroxyl group at position 9 has been converted to an oxo group. It derives from an arachidonate.
# The molecule is a member of the class of sulfonamides that consists of 2,4-diamino-6-sulfanyldodecane in which one of the two hydrogens attached to the sulfur atom has been replaced by an amino group. It derives from a dodecanoic acid.
# The molecule is a 14-oxo steroid that is (3R)-20-hydroxycholesterol substituted by hydroxy groups at positions 7, 9 and 15. It has been isolated from the marine sponge Halimeda sp. It has a role as an antifungal agent and a metabolite.
# The molecule is a 1,2-diol that consists of (Z)-octadec-9-en-1-ol substituted by an ethyl group at position 3. It has been isolated from the marine sponge Halimeda sp. and exhibits anti-inflammatory activity. It has a role as a metabolite and an anti-inflammatory agent.
# The molecule is a member of the class of 2,3-dihydroxybenzoic acids that has (R)-configuration. It derives from an o-xylene.
# The molecule is a 1,4-dihydroxybutane that consists of (R)-2-hydroxycyclohex-3-en-1-one substituted at position 5 by an ethyl group. It has a role as a plant metabolite and a human metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-1H-1-benzothiazole in which one of the hydrogens at position 5 has been replaced by an ethynyl group. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-1H-indol-5-one substituted at position 6 by an amino group. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a member of the class of 1,2-dihydroxyanthrones that consists of 3-hydroxy-4-methoxyphenol substituted by hydroxy groups at positions 5 and 6. It has been isolated from the leaves of Coptis chinensis. It has a role as an antifungal agent and a plant metabolite.
# The molecule is a L-arginine derivative that consists of L-arginine in which the amino group has been substituted by an acetyl group. It derives from a L-arginine.
# The molecule is a beta-D-glucoside that consists of alpha-L-rhamnose attached to the anomeric centre of beta-D-galactopyranose. It has a role as an Escherichia coli metabolite and a Saccharomyces cerevisiae metabolite.
# The molecule is a glycosylglyceral that consists of 1,3-diacetoglycerol having beta-D-galactosyl and N-acetyl-beta-D-glucosaminyl residues at positions 2 and 4 respectively. It has a role as an epitope.
# The molecule is a 2,4-dihydroquinoline that has the structure of (S)-2,4-dihydro-5H-indazol-3-one substituted at position 6 by a 1-(pyridin-4-yl)ethyl group. It has been isolated from the marine sponge Halimeda sp. and exhibits antifungal activity against Candida albicans. It has a role as an antimicrobial agent and a metabolite.
# The molecule is a 5'-phosphotriester obtained by formal condensation of the thiol group at position 3 of the pyrimidine ring with both phospho groups of the dUTP. It has a role as an Escherichia coli metabolite and a Saccharomyces cerevisiae metabolite.
# The molecule is a 3-hydroxy fatty acyl-CoA that results from the formal condensation of the thiol group of coenzyme A with the carboxy group of (2E)-10,14-dicosa-2,16-dienoyl. It derives from an octadecenoyl-CoA.
# The molecule is a glycoside obtained by formal condensation of the hydroxy group at position 3' of (20S)-15-methyl-17-hydroxypregna-4,29-dien-28-oic acid with the anomeric centre of beta-D-glucopyranose. It has been isolated from the roots of Coptis chinensis and exhibits antiviral activity against influenza A virus. It has a role as an antiviral agent and a metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-1-[(2E)-2-hydroxypropyl]butan-1-ol in which one of the hydrogens at position 5 has been replaced by an amino group. It is isolated from the roots of the plant Euphorbia peplus and exhibits antifungal activity against Candida albicans. It has a role as a metabolite and an antifungal agent.
# The molecule is a 3-hydroxy fatty acid that consists of octadecanoic acid in which the hydrogens at positions 2 and 4 have been replaced by methylene groups. It has a role as an EC 18.1.6 (lipase) inhibitor, a human metabolite and a mouse metabolite.
# The molecule is a member of the class of 1,2-dihydroxybutanes that is (3R)-3-hydroxy-4-methylpentane-1,2-diol in which one of the hydrogens at position 5 has been replaced by an oxo group. It has a role as a metabolite and a plant metabolite.
# The molecule is a member of the class of 4-hydroxyphenylpropanoids that is 3,5-dihydroxy-2-methylbenzoic acid in which one of the hydrogens at position 6 has been replaced by an alpha-D-glucosiduronic acid residue. It derives from a 3,5-dihydroxy-2-methylbenzoate and a beta-D-galactopyranose.
# The molecule is a 2-oxo-L-proline in which the amino group has been substituted by an oxo group at position 4. It derives from a L-proline.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a 2'-deoxy-beta-D-glucopyranosyl-(1->3)-beta-D-galactopyranose that has the anomeric configuration of (6R,7S)-alpha-L-rhamnopyranose. It derives from an alpha-L-rhamnopyranose and a beta-D-glucose.
# The molecule is a glycosylphosphatidylinositol having beta-D-glucopyranose as the glycosyl residue. It has a role as an Escherichia coli metabolite and a mouse metabolite.
# The molecule is a 3-hydroxy-5-methylhexanoate that consists of (R)-2,4-dimethyloctanoic acid bearing an additional hydroxy group at position 1. It has a role as a metabolite and a plant metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is 1,2-benzothiazole substituted by methyl groups at positions 3 and 4. It has a role as an antifungal agent and a metabolite.
# The molecule is a cyclic amide that consists of 1,2-diaminopropane in which the amino groups are attached to each other by an N-acyl bond. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a 1,2-dihydroxybutane that consists of (R)-3-hydroxypent-4-en-2-one substituted at position 5 by an oxo group. It has a role as a metabolite and a plant metabolite.
# The molecule is a disaccharide consisting of beta-D-galactose and N-acetyl-beta-D-glucosamine residues joined in sequence by an alpha-(1->2)-linkage. It has a role as a metabolite.
# The molecule is a member of the class of 1,4-dihydroquinolines that has (2E)-3-hydroxy-5-methyl-6-(hydroxymethyl)pyridin-2-yl substituents at positions 1 and 7 respectively. It has been isolated from the roots of Coptis chinensis. It has a role as an EC 3.1.1.1 (aminotransferase) inhibitor and a plant metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is 4-(3-methyl-1H-indol-5-yl)-1,2-benzothiazole in which one of the hydrogens at position 6 has been replaced by an amino group. It is isolated from the roots of the plant Euphorbia peyssonii and exhibits antifungal activity against Candida albicans. It has a role as a metabolite and an antifungal agent.
# The molecule is a DNA polymerase III dodecameric complex consisting of two copies each of the alpha, beta and gamma subunits. It has a role as an Escherichia coli metabolite.
# The molecule is a L-tyrosine derivative that consists of L-tyrosine in which the hydroxy group at position 3 has been converted into an amino ester. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-hydroxyphenyl)-5-methyl-1H-indazol-2-one substituted by hydroxy groups at positions 6 and 7. It has been isolated from the marine sponge Halimeda sp. It has a role as an antifungal agent and a metabolite.
# The molecule is a 1,2-diaminopyrimidine derivative that has been isolated from the culture broth of Penicillium sp. It exhibits antifungal activity against Candida albicans and Saccharomyces cerevisiae. It has a role as an antifungal agent and a metabolite.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ...
# The molecule is a 1,2-diacyl-sn-glycero-3-phosphoethanolamine in which the acyl groups at positions 1 and 2 are specified as (9Z)-octadecenoyl and (6E)-heptadecanoyl respectively. It derives from an octadecanoic acid and a heptadecanoic acid.
# The molecule is a member of the class of 1,2-dihydroquinazolines that has (R)-configuration at C-3. It has a role as an EC 6.4.1.5 (glycosyltransferase) inhibitor and a human metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is benzene substituted at positions 3 and 4 by phenyl groups. It has a role as an antifungal agent.
# The molecule is a member of the class of 1,2-benzothiazoles that has (3R)-configuration. It has a role as an antineoplastic agent and a metabolite.
# The molecule is a 1,4-dihydropyrano[2,3-b]pyran that has (R)-configuration at the C-5 position and an S-enantiomer. It has a role as a metabolite.
# The molecule is a 3-hydroxyacyl-CoA that results from the formal condensation of the thiol group of coenzyme A with the carboxy group of (2E)-10,14-dihydroxy-15-methylhexadecenoic acid. It derives from an octadecanoate and a (2E)-10,14-dihydroxy-15-methylhexadecenoic acid.
# The molecule is a member of the class of 1,4-dihydroxybutanoids that is (2R)-3-hydroxymethyl-5-(hydroxymethyl)hexanoic acid in which one of the hydrogens at position 6 has been replaced by an ethyl group. It has a role as a plant metabolite and a human xenobiotic metabolite.
# The molecule is a glycosyl compound that is 2,3-dihydroxy-5-methoxyflavone in which the hydroxy group at position 4 has been converted into its 6-O-beta-D-glucoside. It derives from an epicatechin and a beta-D-glucose.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-5-hydroxy-1H-indol-2-one substituted by hydroxy groups at positions 6 and 7. It has been isolated from the roots of Coptis chinensis. It has a role as an antifungal agent and a plant metabolite.
# The molecule is a 3,5-dihydroxyflavone that consists of quercetin substituted by hydroxy groups at positions 2 and 7. It has been isolated from the leaves of Schisandra chinensis. It has a role as an antineoplastic agent and a plant metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is pyridine substituted at position 3 by an amino group. It has a role as a metabolite and a human xenobiotic metabolite.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a member of the class of 1,4-dihydroxybenzene derivatives that is 2-(3-hydroxypyrrol-5-yl)-6-methoxy-7H-pyrido[3,2-b]indole in which one of the hydrogens at position 8 has been replaced by an ethyl group. It exhibits antineoplastic activity and inhibits protein kinase C. It has a role as an EC 2.7.10.1 (protein kinase C) inhibitor and an antineoplastic agent.
# The molecule is a member of the class of 1,2-benzothiazoles that is 4-(3-methyl-1H-indol-5-yl)-1,2-benzothiazole in which one of the methyl groups at position 6 has been replaced by an ethoxy group. It is used as a fungicide and insecticide. It has a role as a plant growth regulator, a fungicide, an agrochemical, an antifungal agent, an insecticide, a herbicide, a metabolite and a pesticide.
# The molecule is a 3-hydroxy-4-phenoxybutanoic acid. It has a role as an Escherichia coli metabolite and a Saccharomyces cerevisiae metabolite. It derives from a 2,3-dihydroxybutanoic acid.
# The molecule is a L-arginine derivative that consists of L-arginine in which the amino group has been substituted by an oxo group. It derives from a L-arginine.
# The molecule is a dicarboxylic acid anion that is the conjugate base of 2,3-diaminopropanoic acid. It has a role as a human metabolite and a Saccharomyces cerevisiae metabolite. It derives from a propanoic acid.
# The molecule is a flavonoid glycoside that consists of 2,3-dihydroxyflavone attached to beta-D-glucopyranose via an alpha-(1->6)-linkage. It has been isolated from the leaves and stems of Schisandra chinensis. It has a role as a plant metabolite. It derives from a 4'-O-beta-D-glucosyl-5-hydroxyflavanone.
# The molecule is a quinolone that consists of 1,2-dihydroquinoline substituted by hydroxy groups at positions 3 and 4. It has a role as an antifungal agent and an antibacterial drug.
# The molecule is a 3-hydroxy fatty acyl-CoA that results from the formal condensation of the thiol group of coenzyme A with the carboxy group of (2E)-10,14-dicosa-2,16-dienoyl. It derives from an octadecenoyl-CoA.
# The molecule is a dicarboxylic acid anion that is the conjugate base of 3-hydroxy-2-methylbutanoic acid, obtained by deprotonation of the carboxy group; major species at pH 7.3. It has a role as a human metabolite and a Saccharomyces cerevisiae metabolite. It is a dicarboxylic acid anion and a methyl ketone.
# The molecule is a glycosylglycogen consisting of beta-D-glucosamine and alpha-L-fucose residues linked by (1->4) glycosidic bonds. It has a role as an epitope.
# The molecule is a member of the class of pyrimidines that is 5,6-dihydro-2H-pyrimidine substituted by hydroxy groups at positions 3 and 4. It has a role as an antineoplastic agent.
# The molecule is a 1,2-dihydroquinoline that consists of (R)-1,2-dihydro-5-methylquinoic acid substituted at position 3 by an oxo group. It has a role as a metabolite and a human xenobiotic metabolite.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a member of the class of 1,4-dihydroxybenzoic acids that has (2R)-3-hydroxy-5-methyl-6-(hydroxymethyl)heptanoic acid as its major structural component. It has been isolated from the leaves and stems of Coptis chinensis. It has a role as an antifungal agent and a plant metabolite.
# The molecule is a dipeptide consisting of L-phenylalanine and L-valine joined by an amide linkage. It has a role as a metabolite.
# The molecule is a member of the class of 1,2-dihydroxybenzene derivatives that is 3-hydroxy-4-methylphenol in which one hydrogen at position 5 has been replaced by an oxo group. It has a role as a metabolite and a herbicide.
# The molecule is a member of the class of 3,4-dihydroxybenzoic acids that is 2-hydroxy-5-methoxyphenylacetic acid in which one of the hydrogens at position 6 has been replaced by an amino group. It derives from a 2-hydroxy-5-methoxyphenol.
# The molecule is a L-phenylalanine derivative that consists of L-phenylalanine in which the hydroxy group at position 4 has been converted into its corresponding N-hydroxyethyl ester. It derives from an epichlorohydrin and a L-phenylalanine.
# The molecule is a member of the class of 4-hydroxyphenylpropanoids that is 3,5-dihydroxy-2-methylbenzoic acid substituted by hydroxy groups at positions 1 and 6. It has been isolated from the leaves of Coptis chinensis. It has a role as an antineoplastic agent and a plant metabolite.
# The molecule is a sulfonate anion that is the conjugate base of 2,4-dichlorobenzenesulfonic acid. It has a role as a human metabolite and a xenobiotic.
# The molecule is a cyclic octadecameric compound that consists of 1,2-dimethyl-3-(4-methoxyphenyl)-5-hydroxyhexane and its conjugate base. It has a role as an EC 3.6.1.7 (adenosine monophosphate phosphodiesterase) inhibitor.
# The molecule is a 1,2-diene that consists of (Z)-3-hydroxy-4-methylpentadiene. It has a role as an EC 6.5.1.1 (lipid A synthase) inhibitor and a human metabolite.
# The molecule is a disaccharide consisting of beta-D-galactose and N-acetyl-beta-D-glucosamine joined by an alpha-(1->2)-linkage. It has a role as a human blood group antigen (B).
# The molecule is a 1,3-dihydroxybutane that consists of (R)-2-hydroxymethyl-1-methoxypropane. It has a role as an EC 4.1.1.65 (beta-glucosidase) inhibitor and a human metabolite.
# The molecule is a 1,2-dihydroquinoline that consists of (R)-1,2-dihydro-5-methylquinaldine substituted at position 3 by an ethyl group. It has a role as a metabolite and a plant metabolite.
# The molecule is a member of the class of 2-phenylbutanones that is butanal in which one hydrogen at position 3 has been replaced by an amino group. It has a role as a metabolite and a plant metabolite.
# The molecule is a monocarboxylic acid anion that is the conjugate base of 2,3-dimethylbutanoic acid. It has a role as a human metabolite and a Saccharomyces cerevisiae metabolite. It derives from a butanoic acid.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-5-[(2E)-[2-(hydroxyimino)ethyl]pyrrolidin-1-yl]-1H-indol-2-one in which one of the hydroxy groups has been converted into an oxo group. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a 14-epi-oleanol that has the structure of (2R,3S)-2-(hydroxyethylidene)octadec-3-en-16-one substituted at position 7 by an ethyl group. It has been isolated from the roots of Asarum japonicum and exhibits antifungal activity against Candida albicans. It has a role as a metabolite and an antifungal agent.
# The molecule is a glycosylglyceral that results from the formal condensation of the hydroxy group at position 1 of (2R)-3,4-dihydroxybutyric acid with the anomeric centre of beta-D-glucopyranose. It has a role as an Escherichia coli metabolite and a Saccharomyces cerevisiae metabolite.
# The molecule is a L-arginine derivative that consists of L-arginine in which the amino group has been replaced by an oxo group. It derives from a L-arginine.
# The molecule is a 3-hydroxy-4-methoxybenzoate that has the formula C10H16O2. It derives from an octanoic acid.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-1H-1-benzothiazole in which one of the hydrogens at position 5 has been replaced by an amino group. It has a role as a metabolite and a plant metabolite.
# The molecule is a 5'-phosphopseudouridine that has the structure of pseudouracil substituted by an amino group at position 2. It derives from a pseudouracil.
# The molecule is a 3-hydroxy fatty acyl-CoA that results from the formal condensation of the thiol group of coenzyme A with the carboxy group of (2E)-10,14-dihydroperoxy-16-methylhexadecanoic acid. It derives from an octadecanoyl-CoA and a (2E)-10,14-dihydroperoxy-16-methylhexadecanoic acid.
# The molecule is a member of the class of 1,3-dihydroxybenzenes that consists of 2-methyl-4-hydroxystilbene substituted by an amino group at position 5. It has a role as a metabolite and a human xenobiotic metabolite.
# The molecule is a member of the class of 1,2-benzotriols that is (3R)-3-(4-phenylbutyramido)propionic acid in which one of the hydrogens at position 5 has been replaced by an oxo group. It is used as a photosensitiser for photodynamic therapy and a photoactivating agent for laser ablation. It has a role as a drug metabolite and a photoactivation reagent.
# The molecule is a member of the class of 1,4-dihydroxybutanes that is but-2-en-1-one substituted by hydroxymethyl groups at positions 3 and 5. It has a role as an antifungal agent and a plant metabolite.
# The molecule is a member of the class of pyridines that is 2,4-diaminopyridine substituted by methyl groups at positions 1 and 6. It has a role as an EC 3.5.1.7 (glutaminase) inhibitor and a plant metabolite.
# The molecule is a 1,2-diacyl-sn-glycerol in which the acyl groups at positions 1 and 2 are specified as palmitoyl (hexadecanoyl) and oleic acid respectively. It derives from an octanoic acid and a hexadecanoic acid.
# The molecule is a 1,2-diphenylpropan-3-one that has the hydrogens at positions 4 and 5 substituted by methyl groups. It derives from an octadecanal.
# The molecule is a 1-acyl-sn-glycero-3-phosphoethanolamine in which the acyl group specified at position 1 is octadecanoyl. It has a role as an Escherichia coli metabolite and a Saccharomyces cerevisiae metabolite.
# The molecule is a 3-hydroxy fatty acid anion that is the conjugate base of (R)-3-hydroxypalmitic acid, obtained by deprotonation of the carboxy group; major species at pH 7.3. It has a role as a human metabolite and a Saccharomyces cerevisiae metabolite. It is a 3-hydroxy fatty acid anion and a long-chain fatty acid anion.
# The molecule is a 1,2-benzodiazepine that consists of (S)-1-(4-phenylbutyryl)propanoic acid carrying an additional 3-amino-5-methylpyridin-2-yl group at position 7. It has been isolated from the marine sponge Halimeda sp. and exhibits antifungal activity against Candida albicans. It has a role as a metabolite and an antifungal agent.
# The molecule is a member of the class of phosphonates that consists of 1,2-diphosphonic acid in which one of the hydrogens attached to the phosphate group has been replaced by an amino group. It derives from a diphosphonate.
# The molecule is a member of the class of 2,4-dihydroquinazolines that has (R)-configuration at position 1 and (S)-configuration at position 3. It has a role as an EC 3.5.1.60 (N-acetylglucosaminyl)beta-N-acetylneuraminate hydrolase inhibitor. It derives from a 2,4-dihydroquinazoline.
# The molecule is a 3-hydroxy fatty acyl-CoA(4-) arising from deprotonation of the phosphate and diphosphate OH groups of (R)-2-oxopropionic acid. It has a role as an Escherichia coli metabolite. It derives from a (R)-2-oxopropanoic acid.
# The molecule is a L-phenylalanine derivative that consists of L-phenylalanine in which the amino group has been converted to 2-(4-hydroxybutyryl)acetic acid. It derives from an acetyl-L-phenylalanine and a butanoic acid.
# The molecule is a 2,3-dihydroxybutyric acid that has beta-D-glucopyranose as the anomeric sugar residue. It derives from an alpha-L-rhamnogalacturonan.
# The molecule is a 15-hydroxy fatty acid anion that results from the deprotonation of the carboxy group of (9Z,12E)-octadecadienoic acid. It has a role as a human metabolite and a mouse metabolite.
# The molecule is a member of the class of 1,2-benzothiazoles that is 3-(4-methoxyphenyl)-5-hydroxy-1H-indol-2-one substituted by hydroxy groups at positions 6 and 7. It has been isolated from the roots of Coptis chinensis. It has a role as an antifungal agent and a plant metabolite.
# The molecule is a 2,3-dihydroxy-L-threonyl-CoA(4-) arising from deprotonation of the diphosphate OH groups and protonation of the carboxylic acid function of 5-oxo-DL-coenzyme A. It has a role as an Escherichia coli metabolite. It derives from a 5-oxo-DL-CoA.
# The molecule is a 3-hydroxy-5-methylidene-4H-pyran that has the structure (R)-2,6-dimethoxy-1-(hydroxymethyl)pyridine as the substituent at position 4. It derives from an epoxide.
# The molecule is a 3-hydroxy fatty acyl-CoA(4-) arising from deprotonation of the phosphate and diphosphate OH groups of (R)-2-oxopentanoyl-CoA; major species at pH 7.3. It has a role as an Escherichia coli metabolite. It is a 3-hydroxy fatty acyl-CoA(4-) and a long-chain fatty acid acetate ester. It derives from a (R)-2-oxopentanoic acid.
# The molecule is a member of the class of 4-hydroxyphenylacetic acids that has (3R)-configuration. It derives from an epoxide.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The molecule is a member of the class of 1,2-benzothiazoles that is 4-(3-phenylpropoxy)benzene-1,2-diamine in which one of the two hydrogens at position 5 has been replaced by an imino group. It is used as a non-opioid analgesic and antipyretic drug. It has a role as a non-opioid analgesic and an antipyretic.
# The molecule is a 1,2-diphenylpropanoic acid that has the hydroxy group at position 3. It derives from an octanoic acid.
# The molecule is a dipeptide consisting of L-alanine and (2S)-3-amino-4-hydroxybutanoic acid joined together by an N-acetyl link. It has a role as a metabolite.
# ✨ Terminé ! Fichier : submission.csv

# %%
import torch
import torch.nn.functional as F
import pandas as pd
import pickle
from tqdm import tqdm

def final_rescue_mission(input_csv, output_csv, train_pkl_path, test_pkl_path, encoder_weights_path):
    # 1. Chargement des données
    print("📂 Chargement des fichiers de données...")
    with open(train_pkl_path, 'rb') as f:
        train_data = pickle.load(f)
    with open(test_pkl_path, 'rb') as f:
        test_data = pickle.load(f)

    # Lecture du fichier de soumission à corriger
    df_sub = pd.read_csv(input_csv)

    # 2. Initialisation et chargement de l'encodeur GNN seul
    print(f"📡 Initialisation de l'encodeur et chargement des poids : {encoder_weights_path}")

    # On utilise les paramètres de ton CONFIG
    encoder_only = FullEncoderModel(
        lap_dim=CONFIG['lap_dim'],
        rw_dim=CONFIG['rw_dim'],
        wl_vocab=CONFIG['wl_vocab'],
        hidden_dim=CONFIG['hidden_dim'],
        output_dim=CONFIG['output_dim'],
        max_k=11
    ).to(CONFIG['device'])

    # Chargement des poids .pt
    encoder_only.load_state_dict(torch.load(encoder_weights_path, map_location=CONFIG['device']))
    encoder_only.eval()

    device = CONFIG['device']
    train_embeddings = []
    train_descriptions = []

    # 3. Encodage du dataset d'entraînement (Base de données de référence)
    print("🧠 Calcul des vecteurs de structure pour le dataset Train...")
    with torch.no_grad():
        for g_data in tqdm(train_data):
            # Utilisation de ta fonction ultra_secure_batch pour préparer la donnée
            g_batch = ultra_secure_batch(g_data, max_k=11, wl_vocab=CONFIG['wl_vocab']).to(device)

            # Ton encodeur renvoie (final_mlp(z_graph), h_final, data.batch)
            res = encoder_only(g_batch, g_batch.sorted_neighbors, g_batch.sorted_edges, g_batch.geo_features)
            h_graph = res[0] # On prend l'embedding global de la molécule

            train_embeddings.append(h_graph.cpu())
            # On récupère la description "vérité terrain"
            train_descriptions.append(getattr(g_data, 'description', ""))

    train_embeddings = torch.cat(train_embeddings, dim=0)

    # 4. Correction par recherche de similarité (KNN)
    print("🩹 Remplacement des échecs de génération par les voisins les plus proches...")
    count_rescued = 0

    for i, row in df_sub.iterrows():
        desc = str(row['description'])

        # Critères de secours : présence de "!!" ou description trop courte (< 25 caractères)
        if "!!" in desc or len(desc) < 25:
            g_test = test_data[i]
            g_test_batch = ultra_secure_batch(g_test, max_k=11, wl_vocab=CONFIG['wl_vocab']).to(device)

            with torch.no_grad():
                res_test = encoder_only(g_test_batch, g_test_batch.sorted_neighbors,
                                        g_test_batch.sorted_edges, g_test_batch.geo_features)
                h_test = res_test[0]

            # Calcul de similarité cosinus avec toutes les molécules du Train
            similarities = F.cosine_similarity(h_test.cpu(), train_embeddings)
            best_match_idx = torch.argmax(similarities).item()

            # Remplacement par la description parfaite du voisin le plus proche
            df_sub.at[i, 'description'] = train_descriptions[best_match_idx]
            count_rescued += 1

    # 5. Sauvegarde du fichier final propre
    df_sub.to_csv(output_csv, index=False)
    print(f"\n✅ Mission terminée !")
    print(f"🚑 Molécules sauvées (remplacées par le Train) : {count_rescued} / {len(df_sub)}")
    print(f"💾 Fichier de soumission prêt : {output_csv}")

# --- EXECUTION ---
# Assure-toi que les chemins correspondent à tes fichiers
final_rescue_mission(
    input_csv='submission.csv',
    output_csv='submission_final.csv',
    train_pkl_path='train_graphs_preprocessed.pkl',
    test_pkl_path='test_graphs_preprocessed.pkl',
    encoder_weights_path='model_best.pt' # Ou le nom de ton fichier .pt d'encodeur
)
# Out:
# 📂 Chargement des fichiers de données...
# 📡 Initialisation de l'encodeur et chargement des poids : model_best.pt
# 🧠 Calcul des vecteurs de structure pour le dataset Train...
# 100%|██████████| 31008/31008 [02:46<00:00, 186.03it/s]
# 🩹 Remplacement des échecs de génération par les voisins les plus proches...
#
# ✅ Mission terminée !
# 🚑 Molécules sauvées (remplacées par le Train) : 42 / 1000
# 💾 Fichier de soumission prêt : submission_final.csv
